# %%
import mammos_entity as me

# %%
# %%time
o = me.Ontology()
o.initialize()
o
# Out:
# CPU times: user 33.1 ms, sys: 4.04 ms, total: 37.1 ms
# Wall time: 43.4 s
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 get_ipython().run_cell_magic('time', '', 'o = me.Ontology()\no.initialize()\no\n')
#
# File <timed exec>:2
#       1 'Could not get source, probably due dynamically evaluated source code.'
#
# File ~/repos/mammos/mammos-entity/src/mammos_entity/_ontology.py:90, in Ontology.initialize(self, verbose, use_cache)
#      85 if self._initialized:
#      86     warnings.warn(
#      87         "Already initialized. Re-initializing.",
#      88         stacklevel=1,
#      89     )
# ---> 90 self._ontopy_ontology = _load_ontologies(self.iris, verbose=verbose, use_cache=use_cache)
#      91 # if self._iris is None:
#      92 #     self._ontopy_ontology, self._iris = _load_local_ontologies(verbose=verbose)
#      93 #     self._local = True
#      94 # else:
#      95 #     self._ontopy_ontology = _load_online_ontologies(self._iris, verbose=verbose)
#      96 #     self._local = False
#      97 self._initialized = True
#
# File ~/repos/mammos/mammos-entity/src/mammos_entity/_ontology.py:274, in _load_ontologies(iris, verbose, use_cache)
#     272             if verbose:
#     273                 print(f"Downloading {iri} (inferred) to {filename}.")
# --> 274             _download_ontology(_iri_to_inferred(iri), filename)
#     275 else:
#     276     to_read = iris
#
# File ~/repos/mammos/mammos-entity/src/mammos_entity/_ontology.py:299, in _download_ontology(url, destination)
#     297 s.mount("https://", requests.adapters.HTTPAdapter(max_retries=retries))
#     298 res = s.get(url)
# --> 299 with open(destination, "w") as f:
#     300     f.write(res.content)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/petrocch/.cache/mammos_entity/magnetic-materials/0.0.5/inferred.ttl'

# %%
ec = me.EntityCollection(Ms=me.Ms(1), Tc=me.Tc(2), arr=[1, 2, 3])
ec

# %%
ec.metadata()

# %%
# %%time
o = me.Ontology(
    iris=[
        "file://emmo-inferred-1.0.2.ttl",
        "file://electrochemistry-inferred-0.37.2.ttl",
    ],
)
o.initialize()

# %%
ec.R = o.Entity("ParticleRadius", 4.0, "nm")
ec

# %%
ec.metadata()

# %%
ss = set(entity.ontology_iri for name, entity in ec if hasattr(entity, "ontology_iri") and not entity.ontology._local)
ss

# %%
metadata = ec.metadata()
metadata

# %%
iris = list(
    entity["ontology_iri"] for entity in metadata.values() if "ontology_iri" in entity and entity["ontology_iri"]
)
iris

# %%
set(
    entity["ontology_iri"]
    for entity in metadata.values()
    if "ontology_iri" in entity and entity["ontology_iri"] not in me.mammos_ontology.iris
)
