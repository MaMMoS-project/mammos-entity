# %%
import mammos_entity as me

# %%
o = me.Ontology(
    iris=[
        "https://w3id.org/emmo/1.0.2",
        "https://w3id.org/emmo/domain/electrochemistry/0.37.2/",
    ],
)

# %%
e = o.Entity("Magnetization")
e
# Out:
# /home/petrocch/repos/mammos/mammos-entity/.pixi/envs/default/lib/python3.11/site-packages/ontopy/ontology.py:852: UserWarning: Recovering from Owlready2 parsing error... might be deprecated
#   warnings.warn(
# Entity(ontology_label='Magnetization', value=np.float64(0.0), unit='A / m')

# %%
mag = e.thing
mag
# Out:
# 1.0.2.Magnetization

# %%
e.ontology_iri
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 e.ontology_iri
#
# File ~/repos/mammos/mammos-entity/src/mammos_entity/_entity.py:387, in Entity.ontology_iri(self)
#     375 @property
#     376 def ontology_iri(self) -> str:
#     377     """The ontology IRI that links the entity to the EMMO ontology.
#     378
#     379     Retrieve the ontology IRI (Internationalized Resource Identifier) corresponding
#    (...)    385
#     386     """
# --> 387     return self.ontology.iri
#
# AttributeError: 'Ontology' object has no attribute 'iri'

# %%
mag.iri
# Out:
# 'https://w3id.org/emmo#EMMO_b23e7251_a488_4732_8268_027ad76d7e37'
