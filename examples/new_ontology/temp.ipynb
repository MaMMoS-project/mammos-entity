# %%
import logging

import mammos_entity as me

logging.basicConfig(format="%(levelname)s:%(message)s", level=logging.DEBUG)

# %%
magmo = me.mammos_ontology
magmo.initialize()
magmo
# Out:
# DEBUG:Using caching of turtle files
# DEBUG:Downloading missing ontologies...
# INFO:Found https://w3id.org/emmo/domain/magnetic-materials/0.0.6/inferred in /home/pepe/.cache/mammos_entity/magnetic-materials/0.0.6/inferred.ttl
# INFO:Reading /home/pepe/.cache/mammos_entity/magnetic-materials/0.0.6/inferred.ttl
# Ontology(['https://w3id.org/emmo/domain/magnetic-materials/0.0.6/inferred'])

# %%
str(list(magmo._ontopy_ontology.classes(imported=True))[4].get_preferred_label())
# Out:
# 'SICoherentDerivedUnit'

# %%
me.Entity("AngularVelocity").entity_iri
# Out:
# 'https://w3id.org/emmo#EMMO_bd325ef5_4127_420c_83d3_207b3e2184fd'

# %%
me.T().entity_iri
# Out:
# 'https://w3id.org/emmo#EMMO_affe07e4_e9bc_4852_86c6_69e26182a17f'
