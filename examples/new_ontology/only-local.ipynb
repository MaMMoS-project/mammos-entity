# %%
import mammos_entity as me

# %%
# %%time
o = me.Ontology(
    iris=[
        "file://emmo-inferred-1.0.2.ttl",
        "file://electrochemistry-inferred-0.37.2.ttl",
    ],
)
# Out:
# CPU times: user 5 μs, sys: 0 ns, total: 5 μs
# Wall time: 7.15 μs

# %%
# %%time
o = me.Ontology(
    iris=[
        "https://w3id.org/emmo/1.0.2",
        "https://w3id.org/emmo/domain/electrochemistry/0.37.2",
    ],
    initialize=True,
)
# Out:
# /home/petrocch/repos/mammos/mammos-entity/.pixi/envs/default/lib/python3.11/site-packages/ontopy/ontology.py:852: UserWarning: Recovering from Owlready2 parsing error... might be deprecated
#   warnings.warn(
# CPU times: user 25.9 ms, sys: 3.85 ms, total: 29.7 ms
# Wall time: 29 ms
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File ~/repos/mammos/mammos-entity/.pixi/envs/default/lib/python3.11/urllib/request.py:1348, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1347 try:
# -> 1348     h.request(req.get_method(), req.selector, req.data, headers,
#    1349               encode_chunked=req.has_header('Transfer-encoding'))
#    1350 except OSError as err: # timeout error
#
# File ~/repos/mammos/mammos-entity/.pixi/envs/default/lib/python3.11/http/client.py:1282, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
# ...

# %%
debug
# Out:
# > /home/petrocch/repos/mammos/mammos-entity/.pixi/envs/default/lib/python3.11/urllib/request.py(1351)do_open()
#    1349                           encode_chunked=req.has_header('Transfer-encoding'))
#    1350             except OSError as err: # timeout error
# -> 1351                 raise URLError(err)
#    1352             r = h.getresponse()
#    1353         except:
# ipdb>  u
# > /home/petrocch/repos/mammos/mammos-entity/.pixi/envs/default/lib/python3.11/urllib/request.py(1391)https_open()
#    1389
#    1390         def https_open(self, req):
# -> 1391             return self.do_open(http.client.HTTPSConnection, req,
#    1392                 context=self._context, check_hostname=self._check_hostname)
#    1393
# ipdb>  u
# > /home/petrocch/repos/mammos/mammos-entity/.pixi/envs/default/lib/python3.11/urllib/request.py(496)_call_chain()
#     494         for handler in handlers:
#     495             func = getattr(handler, meth_name)
# --> 496             result = func(*args)
# ...

# %%
# %%time
e = o.Entity("Magnetization")
e
# Out:
# CPU times: user 14 μs, sys: 1 μs, total: 15 μs
# Wall time: 17.4 μs
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 get_ipython().run_cell_magic('time', '', 'e = o.Entity("Magnetization")\ne\n')
#
# File <timed exec>:1
# ----> 1 'Could not get source, probably due dynamically evaluated source code.'
#
# File ~/repos/mammos/mammos-entity/src/mammos_entity/_ontology.py:168, in Ontology.Entity(self, ontology_label, value, unit, iri, description)
#     166 """TODO: docstring."""
#     167 if not self._initialized:
# --> 168     self.initialize()
#     169 return Entity(ontology_label, value, unit, iri=iri, description=description, ontology=self)
#
# File ~/repos/mammos/mammos-entity/src/mammos_entity/_ontology.py:90, in Ontology.initialize(self, verbose, use_cache)
#      85 if self._initialized:
#      86     warnings.warn(
# ...

# %%
e.ontology_iri
# Out:
# 'https://w3id.org/emmo/1.0.2/emmo'

# %%
e.entity_iri
# Out:
# 'https://w3id.org/emmo#EMMO_b23e7251_a488_4732_8268_027ad76d7e37'

# %%
e = o.Entity("3DArray")
e
# Out:
# Entity(ontology_label='Array3D', value=np.float64(0.0))

# %%
e.ontology_iri
# Out:
# 'https://w3id.org/emmo/1.0.2/emmo'

# %%
e.entity_iri
# Out:
# 'https://w3id.org/emmo#EMMO_20ff3b34_c864_4936_8955_9345fc0a3b3c'

# %%
e = o.Entity("ElectricPotentialSignal")
e
# Out:
# Entity(ontology_label='ElectricPotentialSignal', value=np.float64(0.0))

# %%
e.ontology_iri
# Out:
# 'https://w3id.org/emmo/domain/electrochemistry/0.37.2/electrochemistry'

# %%
e.entity_iri
# Out:
# 'https://w3id.org/emmo/domain/electrochemistry#electrochemistry_0a03ce7e_d79f_412e_a103_b5d74de9f4d7'
