# %%
import mammos_entity as me

# %% [markdown]
# ## Str

# %%
o = me.Ontology()

# %%
print(str(o))

# %%
o = me.Ontology(
    iris=[
        "https://w3id.org/emmo/1.0.2",
        "https://w3id.org/emmo/domain/electrochemistry/0.37.2/",
    ],
)

# %%
print(str(o))

# %% [markdown]
# ## lazy init

# %%
# %%time
o.initialize(verbose=True)

# %%
# %%time
o.Entity("Magnetization", 1.2)

# %% [markdown]
# Otherwise it initialize the first time it is needed.

# %%
# %%time
o = me.Ontology(
    iris=[
        "https://w3id.org/emmo/1.0.2",
        "https://w3id.org/emmo/domain/electrochemistry/0.37.2/",
    ],
)
o.Entity("Magnetization", 2.0)

# %% [markdown]
# And the successive calls are much faster.

# %%
# %%time
e = o.Entity("Magnetization", 3.0)
e

# %% [markdown]
# ## attributes

# %%
e.ontology_iri

# %%
e.entity_iri

# %%
e.thing

# %% [markdown]
# ## use other ontologies

# %%
e = o.Entity("ElectricPotentialSignal", 3)  # from battery
e

# %%
e.ontology_iri

# %%
e.entity_iri

# %%
e.thing

# %%
e.thing.elucidation

# %% [markdown]
# ## same ontology - different version

# %%
import mammos_entity as me

# %%
o = me.Ontology(
    iris=[
        "https://w3id.org/emmo/1.0.2",
        "https://w3id.org/emmo/1.0.3",
    ],
)

# %%
o.iris  # most recent appears first

# %%
mag = o.Entity("ElementaryCharge", 4.0)
mag

# %%
match = o._ontopy_ontology.search(prefLabel="ElementaryCharge")[0]

# %%
match.namespace.get_version(as_iri=True)

# %%
mag.ontology

# %%
mag.thing

# %% [markdown]
# (if we do not care about IRI, it will load the first one it finds)

# %% [markdown]
# ## Add ontology iris later

# %%
import mammos_entity as me

# %%
o = me.Ontology(
    iris=[
        "https://w3id.org/emmo/1.0.2",
    ],
)

# %%
o.iris  # most recent appears first

# %%
o.add_iri("https://w3id.org/emmo/1.0.3")
o.iris

# %% [markdown]
# Adding an already included ontology will warn:

# %%
o.add_iri("https://w3id.org/emmo/1.0.3")

# %% [markdown]
# If the ontology was initialized, adding another IRI will load the corresponding ontology. If it was not initialized, it will not load.

# %% [markdown]
# ## Local ontologies

# %%
import mammos_entity as me

# %%
# %%time
o = me.Ontology(
    iris=[
        "file://emmo-inferred-1.0.2.ttl",
        "file://electrochemistry-inferred-0.37.2.ttl",
    ],
)
o.initialize()

# %%
o.iris

# %% [markdown]
# ## mammos_ontology

# %%
import mammos_entity as me

# %%
# %%time
o = me.Ontology()
o.initialize()
o

# %%
print(str(o))

# %%
Ms = o.Entity("SpontaneousMagnetization", 1)
Ms

# %%
me.mammos_ontology

# %%
print(str(me.mammos_ontology))

# %%
Ms = me.Ms(2)
Ms

# %%
Ms.ontology_iri

# %%
print(str(me.mammos_ontology))

# %% [markdown]
# ## Data and metadata

# %%
import mammos_entity as me

# %%
ec = me.EntityCollection(Ms=me.Ms(1), Tc=me.Tc(2), arr=[0.5])
ec
# Out:
# EntityCollection(
#     Ms=Entity(ontology_label=locstr('SpontaneousMagnetization', 'en-US'), value=np.float64(1.0), unit='A / m'),
#     Tc=Entity(ontology_label=locstr('CurieTemperature', 'en'), value=np.float64(2.0), unit='K'),
#     arr=[0.5],
# )

# %% [markdown]
# Add entity from another ontology.

# %%
o = me.Ontology(
    iris=[
        "file://electrochemistry-inferred-0.37.2.ttl",
    ],
)
o.initialize()
ec.EC = o.Entity("ElementaryCharge", 4.0)

# %%
data = ec.to_dataframe()
data
# Out:
#     Ms   Tc  arr   EC
# 0  1.0  2.0  0.5  4.0

# %%
metadata = ec.metadata()
metadata
# Out:
# {'Ms': {'ontology_label': locstr('SpontaneousMagnetization', 'en-US'),
#   'ontology_iri': 'https://w3id.org/emmo/domain/0.0.5/magnetic-materials',
#   'entity_iri': 'https://w3id.org/emmo/domain/magnetic-materials#EMMO_032731f8-874d-5efb-9c9d-6dafaa17ef25',
#   'unit': 'A / m',
#   'description': ''},
#  'Tc': {'ontology_label': locstr('CurieTemperature', 'en'),
#   'ontology_iri': 'https://w3id.org/1.0.3/emmo',
#   'entity_iri': 'https://w3id.org/emmo#EMMO_6b5af5a8_a2d8_4353_a1d6_54c9f778343d',
#   'unit': 'K',
#   'description': ''},
#  'arr': {},
#  'EC': {'ontology_label': locstr('ElementaryCharge', 'en'),
#   'ontology_iri': 'https://w3id.org/emmo/domain/electrochemistry/0.37.2/electrochemistry',
#   'entity_iri': 'https://w3id.org/emmo#EMMO_58a650f0_a638_4743_8439_535a325e5c4c',
#   'unit': 'A s',
#   'description': ''}}

# %%
# %%time
me.EntityCollection.from_dataframe(data, metadata)
# Out:
# /home/petrocch/repos/mammos/mammos-entity/.pixi/envs/default/lib/python3.11/site-packages/ontopy/ontology.py:852: UserWarning: Recovering from Owlready2 parsing error... might be deprecated
#   warnings.warn(
# CPU times: user 7.98 s, sys: 229 ms, total: 8.2 s
# Wall time: 1min 38s
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File ~/repos/mammos/mammos-entity/.pixi/envs/default/lib/python3.11/site-packages/ontopy/ontology.py:809, in Ontology._load(self, only_local, filename, format, reload, reload_if_newer, url_from_catalog, catalog_file, **kwargs)
#     808 try:
# --> 809     graph.parse(resolved_url, format=fmt)
#     810 except URLError as err:
#
# File ~/repos/mammos/mammos-entity/.pixi/envs/default/lib/python3.11/site-packages/rdflib/graph.py:1625, in Graph.parse(self, source, publicID, format, location, file, data, **args)
#    1539 """Parse an RDF source adding the resulting triples to the Graph.
#    1540
#    1541 The source is specified using one of source, location, file or data.
#    (...)   1622     documentation.
#    1623 """
# -> 1625 source = create_input_source(
#    1626     source=source,
#    1627     publicID=publicID,
#    1628     location=location,
#    1629     file=file,
#    1630     data=data,
#    1631     format=format,
#    1632 )
#    1633 if format is None:
#
# File ~/repos/mammos/mammos-entity/.pixi/envs/default/lib/python3.11/site-packages/rdflib/parser.py:732, in create_input_source(source, publicID, location, file, data, format)
#     726         assert source is None
#     727     (
#     728         absolute_location,
#     729         auto_close,
#     730         file,
#     731         input_source,
# --> 732     ) = _create_input_source_from_location(
#     733         file=file,
#     734         format=format,
#     735         input_source=input_source,
#     736         location=location,
#     737     )
#     739 if file is not None:
#
# File ~/repos/mammos/mammos-entity/.pixi/envs/default/lib/python3.11/site-packages/rdflib/parser.py:794, in _create_input_source_from_location(file, format, input_source, location)
#     793 else:
# --> 794     input_source = URLInputSource(absolute_location, format)
#     796 auto_close = True
#
# File ~/repos/mammos/mammos-entity/.pixi/envs/default/lib/python3.11/site-packages/rdflib/parser.py:591, in URLInputSource.__init__(self, system_id, format)
#     589 req = Request(system_id, None, myheaders)  # type: ignore[arg-type]
# --> 591 response: addinfourl = _urlopen(req)
#     592 self.url = response.geturl()  # in case redirections took place
#
# File ~/repos/mammos/mammos-entity/.pixi/envs/default/lib/python3.11/site-packages/rdflib/_networking.py:112, in _urlopen(request)
#     111 try:
# --> 112     return urlopen(request)
#     113 except HTTPError as error:
#
# File ~/repos/mammos/mammos-entity/.pixi/envs/default/lib/python3.11/urllib/request.py:216, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     215     opener = _opener
# --> 216 return opener.open(url, data, timeout)
#
# File ~/repos/mammos/mammos-entity/.pixi/envs/default/lib/python3.11/urllib/request.py:525, in OpenerDirector.open(self, fullurl, data, timeout)
#     524     meth = getattr(processor, meth_name)
# --> 525     response = meth(req, response)
#     527 return response
#
# File ~/repos/mammos/mammos-entity/.pixi/envs/default/lib/python3.11/urllib/request.py:634, in HTTPErrorProcessor.http_response(self, request, response)
#     633 if not (200 <= code < 300):
# --> 634     response = self.parent.error(
#     635         'http', request, response, code, msg, hdrs)
#     637 return response
#
# File ~/repos/mammos/mammos-entity/.pixi/envs/default/lib/python3.11/urllib/request.py:557, in OpenerDirector.error(self, proto, *args)
#     556 args = (dict, proto, meth_name) + args
# --> 557 result = self._call_chain(*args)
#     558 if result:
#
# File ~/repos/mammos/mammos-entity/.pixi/envs/default/lib/python3.11/urllib/request.py:496, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     495 func = getattr(handler, meth_name)
# --> 496 result = func(*args)
#     497 if result is not None:
#
# File ~/repos/mammos/mammos-entity/.pixi/envs/default/lib/python3.11/urllib/request.py:749, in HTTPRedirectHandler.http_error_302(self, req, fp, code, msg, headers)
#     747 fp.close()
# --> 749 return self.parent.open(new, timeout=req.timeout)
#
# File ~/repos/mammos/mammos-entity/.pixi/envs/default/lib/python3.11/urllib/request.py:525, in OpenerDirector.open(self, fullurl, data, timeout)
#     524     meth = getattr(processor, meth_name)
# --> 525     response = meth(req, response)
#     527 return response
#
# File ~/repos/mammos/mammos-entity/.pixi/envs/default/lib/python3.11/urllib/request.py:634, in HTTPErrorProcessor.http_response(self, request, response)
#     633 if not (200 <= code < 300):
# --> 634     response = self.parent.error(
#     635         'http', request, response, code, msg, hdrs)
#     637 return response
#
# File ~/repos/mammos/mammos-entity/.pixi/envs/default/lib/python3.11/urllib/request.py:563, in OpenerDirector.error(self, proto, *args)
#     562 args = (dict, 'default', 'http_error_default') + orig_args
# --> 563 return self._call_chain(*args)
#
# File ~/repos/mammos/mammos-entity/.pixi/envs/default/lib/python3.11/urllib/request.py:496, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     495 func = getattr(handler, meth_name)
# --> 496 result = func(*args)
#     497 if result is not None:
#
# File ~/repos/mammos/mammos-entity/.pixi/envs/default/lib/python3.11/urllib/request.py:643, in HTTPDefaultErrorHandler.http_error_default(self, req, fp, code, msg, hdrs)
#     642 def http_error_default(self, req, fp, code, msg, hdrs):
# --> 643     raise HTTPError(req.full_url, code, msg, hdrs, fp)
#
# HTTPError: HTTP Error 404: Not Found
#
# The above exception was the direct cause of the following exception:
#
# EMMOntoPyException                        Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 get_ipython().run_cell_magic('time', '', 'me.EntityCollection.from_dataframe(data, metadata)\n')
#
# File <timed eval>:1
# ----> 1 'Could not get source, probably due dynamically evaluated source code.'
#
# File ~/repos/mammos/mammos-entity/src/mammos_entity/_entity_collection.py:364, in EntityCollection.from_dataframe(cls, dataframe, metadata, description)
#     362 if "https://w3id.org/emmo/domain/0.0.5/magnetic-materials" in iris:
#     363     iris.add("https://w3id.org/emmo/domain/magnetic-materials/0.0.5/magnetic-materials-dependencies")
# --> 364 ontology = me.Ontology(iris=iris, initialize=True)
#     366 collection = cls(description=description)
#     367 for name in metadata:
#
# File ~/repos/mammos/mammos-entity/src/mammos_entity/_ontology.py:40, in Ontology.__init__(self, iris, initialize)
#      38 self._initialized = False
#      39 if initialize:
# ---> 40     self.initialize()
#
# File ~/repos/mammos/mammos-entity/src/mammos_entity/_ontology.py:81, in Ontology.initialize(self, verbose)
#      79     self._local = True
#      80 else:
# ---> 81     self._ontopy_ontology = _load_online_ontologies(self._iris, verbose=verbose)
#      82     self._local = False
#      83 self._initialized = True
#
# File ~/repos/mammos/mammos-entity/src/mammos_entity/_ontology.py:206, in _load_online_ontologies(iris, verbose)
#     204     if verbose:
#     205         print(f"Reading {iri}")
# --> 206     dep = world.get_ontology(iri).load()
#     207     onto.imported_ontologies.append(dep)
#     208 return onto
#
# File ~/repos/mammos/mammos-entity/.pixi/envs/default/lib/python3.11/site-packages/ontopy/ontology.py:675, in Ontology.load(self, only_local, filename, format, reload, reload_if_newer, url_from_catalog, catalog_file, emmo_based, prefix, prefix_emmo, **kwargs)
#     673 if self.loaded:
#     674     return self
# --> 675 self._load(
#     676     only_local=only_local,
#     677     filename=filename,
#     678     format=format,
#     679     reload=reload,
#     680     reload_if_newer=reload_if_newer,
#     681     url_from_catalog=url_from_catalog,
#     682     catalog_file=catalog_file,
#     683     **kwargs,
#     684 )
#     686 # Enable optimised search by get_by_label()
#     687 if self._special_labels is None and emmo_based:
#
# File ~/repos/mammos/mammos-entity/.pixi/envs/default/lib/python3.11/site-packages/ontopy/ontology.py:811, in Ontology._load(self, only_local, filename, format, reload, reload_if_newer, url_from_catalog, catalog_file, **kwargs)
#     809     graph.parse(resolved_url, format=fmt)
#     810 except URLError as err:
# --> 811     raise EMMOntoPyException(
#     812         "URL error", err, resolved_url
#     813     ) from err
#     815 with tempfile.NamedTemporaryFile() as handle:
#     816     graph.serialize(destination=handle, format="xml")
#
# EMMOntoPyException: ('URL error', <HTTPError 404: 'Not Found'>, 'https://w3id.org/emmo/domain/0.0.5/magnetic-materials')
