# %%
import logging

import mammos_entity as me

logging.basicConfig(format="%(levelname)s:%(message)s", level=logging.DEBUG)

# %% [markdown]
# ## Str

# %%
o = me.Ontology()

# %%
print(str(o))
# Out:
# Ontology:
# - https://w3id.org/emmo/domain/magnetic-materials/0.0.5/inferred

# %%
o = me.Ontology(
    iris=[
        "https://w3id.org/emmo/1.0.2",
        "https://w3id.org/emmo/domain/electrochemistry/0.37.2/",
    ],
)

# %%
print(str(o))
# Out:
# Ontology:
# - https://w3id.org/emmo/1.0.2
# - https://w3id.org/emmo/domain/electrochemistry/0.37.2/

# %% [markdown]
# ## lazy init

# %%
# %%time
o.initialize()
# Out:
# DEBUG:Initializing with iris=['https://w3id.org/emmo/1.0.2', 'https://w3id.org/emmo/domain/electrochemistry/0.37.2/']
# DEBUG:Using caching of turtle files
# DEBUG:Downloading missing ontologies...
# INFO:Downloading https://w3id.org/emmo/1.0.2/inferred (inferred) to /home/petrocch/.cache/mammos_entity/emmo/1.0.2/inferred.ttl.
# DEBUG:Starting new HTTPS connection (1): w3id.org:443
# DEBUG:https://w3id.org:443 "GET /emmo/1.0.2/inferred HTTP/1.1" 303 50
# DEBUG:Starting new HTTPS connection (1): emmo-repo.github.io:443
# DEBUG:https://emmo-repo.github.io:443 "GET /versions/1.0.2/emmo-inferred.ttl HTTP/1.1" 200 3986208
# INFO:Downloading https://w3id.org/emmo/domain/electrochemistry/0.37.2/inferred (inferred) to /home/petrocch/.cache/mammos_entity/electrochemistry/0.37.2/inferred.ttl.
# DEBUG:Starting new HTTPS connection (1): w3id.org:443
# DEBUG:https://w3id.org:443 "GET /emmo/domain/electrochemistry/0.37.2/inferred HTTP/1.1" 303 50
# ...

# %%
# %%time
o.Entity("Magnetization", 1.2)
# Out:
# CPU times: user 19.1 ms, sys: 111 μs, total: 19.2 ms
# Wall time: 18 ms
# Entity(ontology_label='Magnetization', value=np.float64(1.2), unit='A / m')

# %% [markdown]
# Otherwise it initialize the first time it is needed.

# %%
# %%time
o = me.Ontology(
    iris=[
        "https://w3id.org/emmo/1.0.2",
        "https://w3id.org/emmo/domain/electrochemistry/0.37.2/",
    ],
)
o.Entity("Magnetization", 2.0)
# Out:
# DEBUG:Initializing with iris=['https://w3id.org/emmo/1.0.2', 'https://w3id.org/emmo/domain/electrochemistry/0.37.2/']
# DEBUG:Using caching of turtle files
# DEBUG:Downloading missing ontologies...
# INFO:Found https://w3id.org/emmo/1.0.2 in /home/petrocch/.cache/mammos_entity/emmo/1.0.2/inferred.ttl
# INFO:Found https://w3id.org/emmo/domain/electrochemistry/0.37.2/ in /home/petrocch/.cache/mammos_entity/electrochemistry/0.37.2/inferred.ttl
# INFO:Reading /home/petrocch/.cache/mammos_entity/emmo/1.0.2/inferred.ttl
# INFO:Reading /home/petrocch/.cache/mammos_entity/electrochemistry/0.37.2/inferred.ttl
# CPU times: user 4.68 s, sys: 79.7 ms, total: 4.76 s
# Wall time: 4.76 s
# Entity(ontology_label='Magnetization', value=np.float64(2.0), unit='A / m')

# %% [markdown]
# And the successive calls are much faster.

# %%
# %%time
e = o.Entity("Magnetization", 3.0)
e
# Out:
# CPU times: user 239 μs, sys: 4 μs, total: 243 μs
# Wall time: 249 μs
# Entity(ontology_label='Magnetization', value=np.float64(3.0), unit='A / m')

# %% [markdown]
# ## attributes

# %%
e.ontology_iri
# Out:
# 'https://w3id.org/emmo/1.0.2/emmo'

# %%
e.entity_iri
# Out:
# 'https://w3id.org/emmo#EMMO_b23e7251_a488_4732_8268_027ad76d7e37'

# %%
e.thing
# Out:
# inferred.Magnetization

# %% [markdown]
# ## use other ontologies

# %%
e = o.Entity("ElectricPotentialSignal", 3)  # from battery
e
# Out:
# Entity(ontology_label='ElectricPotentialSignal', value=np.float64(3.0))

# %%
e.ontology_iri
# Out:
# 'https://w3id.org/emmo/domain/electrochemistry/0.37.2/electrochemistry'

# %%
e.entity_iri
# Out:
# 'https://w3id.org/emmo/domain/electrochemistry#electrochemistry_0a03ce7e_d79f_412e_a103_b5d74de9f4d7'

# %%
e.thing
# Out:
# inferred.ElectricPotentialSignal

# %%
e.thing.elucidation
# Out:
# [locstr('Time-dependent variation of electric potential', 'en')]

# %% [markdown]
# ## same ontology - different version

# %%
import mammos_entity as me

# %%
o = me.Ontology(
    iris=[
        "https://w3id.org/emmo/1.0.2",
        "https://w3id.org/emmo/1.0.3",
    ],
)

# %%
o.iris  # most recent appears first
# Out:
# ['https://w3id.org/emmo/1.0.2', 'https://w3id.org/emmo/1.0.3']

# %%
mag = o.Entity("ElementaryCharge", 4.0)
mag
# Out:
# DEBUG:Initializing with iris=['https://w3id.org/emmo/1.0.2', 'https://w3id.org/emmo/1.0.3']
# DEBUG:Using caching of turtle files
# DEBUG:Downloading missing ontologies...
# INFO:Found https://w3id.org/emmo/1.0.2 in /home/petrocch/.cache/mammos_entity/emmo/1.0.2/inferred.ttl
# INFO:Downloading https://w3id.org/emmo/1.0.3/inferred (inferred) to /home/petrocch/.cache/mammos_entity/emmo/1.0.3/inferred.ttl.
# DEBUG:Starting new HTTPS connection (1): w3id.org:443
# DEBUG:https://w3id.org:443 "GET /emmo/1.0.3/inferred HTTP/1.1" 303 50
# DEBUG:Starting new HTTPS connection (1): emmo-repo.github.io:443
# DEBUG:https://emmo-repo.github.io:443 "GET /versions/1.0.3/emmo-inferred.ttl HTTP/1.1" 200 4048089
# INFO:Reading /home/petrocch/.cache/mammos_entity/emmo/1.0.2/inferred.ttl
# INFO:Reading /home/petrocch/.cache/mammos_entity/emmo/1.0.3/inferred.ttl
# ...

# %%
o.iris
# Out:
# ['https://w3id.org/emmo/1.0.2', 'https://w3id.org/emmo/1.0.3']

# %%
mag.ontology
# Out:
# Ontology(['https://w3id.org/emmo/1.0.2', 'https://w3id.org/emmo/1.0.3'])

# %%
o._ontopy_ontology.imported_ontologies
# Out:
# [get_ontology("https://w3id.org/emmo#"),
#  get_ontology("https://w3id.org/emmo/inferred#")]

# %%
o._ontopy_ontology.imported_ontologies[0].get_version(as_iri=True)
# Out:
# 'https://w3id.org/emmo/1.0.2/emmo'

# %%
o._ontopy_ontology.imported_ontologies[1].get_version(as_iri=True)
# Out:
# 'https://w3id.org/1.0.3/emmo'

# %%
mag.thing
# Out:
# inferred.ElementaryCharge

# %% [markdown]
# (if we do not care about IRI, it will load the first one it finds)

# %% [markdown]
# ## Add ontology iris later

# %%
import mammos_entity as me

# %%
o = me.Ontology(
    iris=[
        "https://w3id.org/emmo/1.0.2",
    ],
)

# %%
o.iris  # most recent appears first
# Out:
# ['https://w3id.org/emmo/1.0.2']

# %%
o.add_iri("https://w3id.org/emmo/1.0.3")
o.iris
# Out:
# ['https://w3id.org/emmo/1.0.2', 'https://w3id.org/emmo/1.0.3']

# %% [markdown]
# Adding an already included ontology will warn:

# %%
o.add_iri("https://w3id.org/emmo/1.0.3")
# Out:
# /home/petrocch/repos/mammos/mammos-entity/src/mammos_entity/_ontology.py:101: UserWarning: IRI: 'https://w3id.org/emmo/1.0.3' was already in the list: ['https://w3id.org/emmo/1.0.2', 'https://w3id.org/emmo/1.0.3'].
#   warnings.warn(

# %% [markdown]
# If the ontology was initialized, adding another IRI will load the corresponding ontology. If it was not initialized, it will not load.

# %% [markdown]
# ## Local ontologies

# %%
import mammos_entity as me

# %%
# %%time
o = me.Ontology(
    iris=[
        "file://emmo-inferred-1.0.2.ttl",
        "file://electrochemistry-inferred-0.37.2.ttl",
    ],
)
o.initialize()
# Out:
# DEBUG:Initializing with iris=['file://emmo-inferred-1.0.2.ttl', 'file://electrochemistry-inferred-0.37.2.ttl']
# DEBUG:Using caching of turtle files
# DEBUG:Downloading missing ontologies...
# DEBUG:file://emmo-inferred-1.0.2.ttl is a local file.
# DEBUG:file://electrochemistry-inferred-0.37.2.ttl is a local file.
# INFO:Reading file://emmo-inferred-1.0.2.ttl
# INFO:Reading file://electrochemistry-inferred-0.37.2.ttl
# CPU times: user 5.09 s, sys: 40 ms, total: 5.13 s
# Wall time: 5.13 s

# %%
o.iris
# Out:
# ['file://emmo-inferred-1.0.2.ttl',
#  'file://electrochemistry-inferred-0.37.2.ttl']

# %% [markdown]
# ## mammos_ontology

# %%
import mammos_entity as me

# %%
# %%time
o = me.Ontology()
o.initialize()
o
# Out:
# DEBUG:Initializing with iris=['https://w3id.org/emmo/domain/magnetic-materials/0.0.5/inferred']
# DEBUG:Using caching of turtle files
# DEBUG:Downloading missing ontologies...
# INFO:Using local MagMO packaged with mammos-entity.
# DEBUG:Copied /home/petrocch/repos/mammos/mammos-entity/src/mammos_entity/ontology/magmo-inferred.ttl to /home/petrocch/.cache/mammos_entity/magnetic-materials/0.0.5/inferred.ttl.
# INFO:Reading /home/petrocch/.cache/mammos_entity/magnetic-materials/0.0.5/inferred.ttl
# CPU times: user 3.12 s, sys: 43.8 ms, total: 3.16 s
# Wall time: 5.15 s
# Ontology(['https://w3id.org/emmo/domain/magnetic-materials/0.0.5/inferred'])

# %%
print(str(o))
# Out:
# Ontology: (initialized)
# - https://w3id.org/emmo/domain/magnetic-materials/0.0.5/inferred

# %%
Ms = o.Entity("SpontaneousMagnetization", 1)
Ms
# Out:
# Entity(ontology_label='SpontaneousMagnetization', value=np.float64(1.0), unit='A / m')

# %%
me.mammos_ontology
# Out:
# Ontology(['https://w3id.org/emmo/domain/magnetic-materials/0.0.5/inferred'])

# %%
print(str(me.mammos_ontology))
# Out:
# Ontology:
# - https://w3id.org/emmo/domain/magnetic-materials/0.0.5/inferred

# %%
Ms = me.Ms(2)
Ms
# Out:
# DEBUG:Initializing with iris=['https://w3id.org/emmo/domain/magnetic-materials/0.0.5/inferred']
# DEBUG:Using caching of turtle files
# DEBUG:Downloading missing ontologies...
# INFO:Found https://w3id.org/emmo/domain/magnetic-materials/0.0.5/inferred in /home/petrocch/.cache/mammos_entity/magnetic-materials/0.0.5/inferred.ttl
# INFO:Reading /home/petrocch/.cache/mammos_entity/magnetic-materials/0.0.5/inferred.ttl
# Entity(ontology_label='SpontaneousMagnetization', value=np.float64(2.0), unit='A / m')

# %%
Ms.ontology_iri
# Out:
# 'https://w3id.org/emmo/domain/magnetic-materials/0.0.5'

# %%
print(str(me.mammos_ontology))
# Out:
# Ontology: (initialized)
# - https://w3id.org/emmo/domain/magnetic-materials/0.0.5/inferred

# %% [markdown]
# ## Data and metadata

# %%
import mammos_entity as me

# %%
ec = me.EntityCollection(Ms=me.Ms(1), Tc=me.Tc(2), arr=[0.5])
ec
# Out:
# EntityCollection(
#     Ms=Entity(ontology_label='SpontaneousMagnetization', value=np.float64(1.0), unit='A / m'),
#     Tc=Entity(ontology_label='CurieTemperature', value=np.float64(2.0), unit='K'),
#     arr=[0.5],
# )

# %% [markdown]
# Add entity from another ontology.

# %%
o = me.Ontology(
    iris=[
        "file://electrochemistry-inferred-0.37.2.ttl",
    ],
)
o.initialize()
ec.EC = o.Entity("ElementaryCharge", 4.0)
# Out:
# DEBUG:Initializing with iris=['file://electrochemistry-inferred-0.37.2.ttl']
# DEBUG:Using caching of turtle files
# DEBUG:Downloading missing ontologies...
# DEBUG:file://electrochemistry-inferred-0.37.2.ttl is a local file.
# INFO:Reading file://electrochemistry-inferred-0.37.2.ttl

# %%
data = ec.to_dataframe()
data
# Out:
#     Ms   Tc  arr   EC
# 0  1.0  2.0  0.5  4.0

# %%
metadata = ec.metadata()
metadata
# Out:
# {'Ms': {'ontology_label': 'SpontaneousMagnetization',
#   'ontology_iri': 'https://w3id.org/emmo/domain/magnetic-materials/0.0.5',
#   'entity_iri': 'https://w3id.org/emmo/domain/magnetic-materials#EMMO_032731f8-874d-5efb-9c9d-6dafaa17ef25',
#   'unit': 'A / m',
#   'description': ''},
#  'Tc': {'ontology_label': 'CurieTemperature',
#   'ontology_iri': 'https://w3id.org/1.0.3/emmo',
#   'entity_iri': 'https://w3id.org/emmo#EMMO_6b5af5a8_a2d8_4353_a1d6_54c9f778343d',
#   'unit': 'K',
#   'description': ''},
#  'arr': {},
#  'EC': {'ontology_label': 'ElementaryCharge',
#   'ontology_iri': 'https://w3id.org/emmo/domain/electrochemistry/0.37.2/electrochemistry',
#   'entity_iri': 'https://w3id.org/emmo#EMMO_58a650f0_a638_4743_8439_535a325e5c4c',
#   'unit': 'A s',
#   'description': ''}}

# %%
iris = set(
    entity["ontology_iri"] for entity in metadata.values() if "ontology_iri" in entity and entity["ontology_iri"]
)
ontology = me.Ontology(iris=iris, initialize=True)
ontology
# Out:
# DEBUG:Initializing with iris=['https://w3id.org/emmo/domain/magnetic-materials/0.0.5', 'https://w3id.org/emmo/domain/electrochemistry/0.37.2/electrochemistry', 'https://w3id.org/1.0.3/emmo']
# DEBUG:Using caching of turtle files
# DEBUG:Downloading missing ontologies...
# INFO:Found https://w3id.org/emmo/domain/magnetic-materials/0.0.5 in /home/petrocch/.cache/mammos_entity/magnetic-materials/0.0.5/inferred.ttl
# INFO:Found https://w3id.org/emmo/domain/electrochemistry/0.37.2/electrochemistry in /home/petrocch/.cache/mammos_entity/electrochemistry/0.37.2/inferred.ttl
# INFO:Found https://w3id.org/1.0.3/emmo in /home/petrocch/.cache/mammos_entity/emmo/1.0.3/inferred.ttl
# INFO:Reading /home/petrocch/.cache/mammos_entity/magnetic-materials/0.0.5/inferred.ttl
# INFO:Reading /home/petrocch/.cache/mammos_entity/electrochemistry/0.37.2/inferred.ttl
# INFO:Reading /home/petrocch/.cache/mammos_entity/emmo/1.0.3/inferred.ttl
# ...

# %%
# %%time
me.EntityCollection.from_dataframe(data, metadata)
# Out:
# DEBUG:Initializing with iris=['https://w3id.org/emmo/domain/magnetic-materials/0.0.5', 'https://w3id.org/emmo/domain/electrochemistry/0.37.2/electrochemistry', 'https://w3id.org/1.0.3/emmo']
# DEBUG:Using caching of turtle files
# DEBUG:Downloading missing ontologies...
# INFO:Found https://w3id.org/emmo/domain/magnetic-materials/0.0.5 in /home/petrocch/.cache/mammos_entity/magnetic-materials/0.0.5/inferred.ttl
# INFO:Found https://w3id.org/emmo/domain/electrochemistry/0.37.2/electrochemistry in /home/petrocch/.cache/mammos_entity/electrochemistry/0.37.2/inferred.ttl
# INFO:Found https://w3id.org/1.0.3/emmo in /home/petrocch/.cache/mammos_entity/emmo/1.0.3/inferred.ttl
# INFO:Reading /home/petrocch/.cache/mammos_entity/magnetic-materials/0.0.5/inferred.ttl
# INFO:Reading /home/petrocch/.cache/mammos_entity/electrochemistry/0.37.2/inferred.ttl
# INFO:Reading /home/petrocch/.cache/mammos_entity/emmo/1.0.3/inferred.ttl
# CPU times: user 9.89 s, sys: 44 ms, total: 9.93 s
# ...

# %%
me.EntityCollection.from_dataframe(data, metadata).metadata()
# Out:
# DEBUG:Initializing with iris=['https://w3id.org/emmo/domain/magnetic-materials/0.0.5', 'https://w3id.org/emmo/domain/electrochemistry/0.37.2/electrochemistry', 'https://w3id.org/1.0.3/emmo']
# DEBUG:Using caching of turtle files
# DEBUG:Downloading missing ontologies...
# INFO:Found https://w3id.org/emmo/domain/magnetic-materials/0.0.5 in /home/petrocch/.cache/mammos_entity/magnetic-materials/0.0.5/inferred.ttl
# INFO:Found https://w3id.org/emmo/domain/electrochemistry/0.37.2/electrochemistry in /home/petrocch/.cache/mammos_entity/electrochemistry/0.37.2/inferred.ttl
# INFO:Found https://w3id.org/1.0.3/emmo in /home/petrocch/.cache/mammos_entity/emmo/1.0.3/inferred.ttl
# INFO:Reading /home/petrocch/.cache/mammos_entity/magnetic-materials/0.0.5/inferred.ttl
# INFO:Reading /home/petrocch/.cache/mammos_entity/electrochemistry/0.37.2/inferred.ttl
# INFO:Reading /home/petrocch/.cache/mammos_entity/emmo/1.0.3/inferred.ttl
# {'Ms': {'ontology_label': 'SpontaneousMagnetization',
# ...
