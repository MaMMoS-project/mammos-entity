# %%
import mammos_entity as me

# %% [markdown]
# ## Str

# %%
o = me.Ontology()

# %%
print(str(o))
# Out:
# Ontology:
# - local `magmo`.

# %%
o = me.Ontology(
    iris=[
        "https://w3id.org/emmo/1.0.2",
        "https://w3id.org/emmo/domain/electrochemistry/0.37.2/",
    ],
)

# %%
print(str(o))
# Out:
# Ontology:
# - https://w3id.org/emmo/1.0.2
# - https://w3id.org/emmo/domain/electrochemistry/0.37.2/

# %% [markdown]
# ## lazy init

# %%
# %%time
o.initialize(verbose=True)
# Out:
# Reading https://w3id.org/emmo/1.0.2
# /home/petrocch/repos/mammos/mammos-entity/.pixi/envs/default/lib/python3.11/site-packages/ontopy/ontology.py:852: UserWarning: Recovering from Owlready2 parsing error... might be deprecated
#   warnings.warn(
# Reading https://w3id.org/emmo/domain/electrochemistry/0.37.2/
# CPU times: user 8.1 s, sys: 318 ms, total: 8.42 s
# Wall time: 2min 2s

# %%
# %%time
o.Entity("Magnetization", 1.2)
# Out:
# CPU times: user 8.12 ms, sys: 0 ns, total: 8.12 ms
# Wall time: 7.64 ms
# Entity(ontology_label='Magnetization', value=np.float64(1.2), unit='A / m')

# %%
# %%time
o = me.Ontology(
    iris=[
        "https://w3id.org/emmo/1.0.2",
        "https://w3id.org/emmo/domain/electrochemistry/0.37.2/",
    ],
)
o.Entity("Magnetization", 2.0)
# Out:
# /home/petrocch/repos/mammos/mammos-entity/.pixi/envs/default/lib/python3.11/site-packages/ontopy/ontology.py:852: UserWarning: Recovering from Owlready2 parsing error... might be deprecated
#   warnings.warn(
# CPU times: user 8.36 s, sys: 305 ms, total: 8.67 s
# Wall time: 2min 5s
# Entity(ontology_label='Magnetization', value=np.float64(1.2), unit='A / m')

# %%
# %%time
o.Entity("Magnetization", 3.0)
# Out:
# CPU times: user 267 μs, sys: 11 μs, total: 278 μs
# Wall time: 281 μs
# Entity(ontology_label='Magnetization', value=np.float64(1.4), unit='A / m')

# %% [markdown]
# ## use other ontologies

# %%
o.Entity("ElectricPotentialSignal", 3)  # from battery
# Out:
# Entity(ontology_label='ElectricPotentialSignal', value=np.float64(3.0))

# %% [markdown]
# ## same ontology - different version

# %%
import mammos_entity as me

# %%
o = me.Ontology(
    iris=[
        "https://w3id.org/emmo/1.0.2",
        "https://w3id.org/emmo/1.0.3",
    ],
)

# %%
mag = o.Entity("ElementaryCharge", 4.0)
mag
# Out:
# /home/petrocch/repos/mammos/mammos-entity/.pixi/envs/default/lib/python3.11/site-packages/ontopy/ontology.py:852: UserWarning: Recovering from Owlready2 parsing error... might be deprecated
#   warnings.warn(
# /home/petrocch/repos/mammos/mammos-entity/src/mammos_entity/_entity.py:256: UserWarning: The ontology contains more than one entry with the given label 'ElementaryCharge' as prefLabel. Matches: [1.0.2.ElementaryCharge, 1.0.3.ElementaryCharge]. Chosen entity EMMO_58a650f0_a638_4743_8439_535a325e5c4c from ontology https://w3id.org/emmo/1.0.2/emmo.
#   warnings.warn(
# Entity(ontology_label='ElementaryCharge', value=np.float64(4.0), unit='A s')

# %%
match = o._ontopy_ontology.search(prefLabel="ElementaryCharge")[0]

# %%
match.namespace.get_version(as_iri=True)
# Out:
# 'https://w3id.org/emmo/1.0.2/emmo'

# %%
mag.ontology

# %%
mag.thing

# %% [markdown]
# (if we do not care about IRI, it will load the first it finds)
