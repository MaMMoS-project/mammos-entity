# %% [markdown]
# # `mammos_entity` quickstart

# %% [markdown]
# ## Some definitions
#
# - a `mammos_units.Quantity` is an object that carries a value and a unit.
#
# - a `mammos_entity.Entity` links a quantity to its definition in the [EMMO ontology](https://github.com/emmo-repo/EMMO) and the [MaMMoS additions for magnetic materials](https://github.com/MaMMoS-project/MagneticMaterialsOntology)

# %%
import mammos_entity as me

# %%
me.mammos_ontology.Magnetization.ancestors()
# Out:
# {emmo.CategorizedPhysicalQuantity,
#  emmo.CausalStructure,
#  emmo.Coded,
#  emmo.CodedByStructure,
#  emmo.Conventional,
#  emmo.DerivedQuantity,
#  emmo.EMMO,
#  emmo.ElectromagneticQuantity,
#  emmo.Fusion,
#  emmo.ISO80000Categorised,
#  emmo.ISQDerivedQuantity,
#  emmo.InternationalSystemOfQuantity,
#  emmo.Item,
#  emmo.Magnetization,
#  emmo.Perspective,
#  emmo.PhysicalQuantity,
#  emmo.PhysicalQuantiyByDefinition,
#  emmo.Property,
#  emmo.Quantity,
#  emmo.QuantityByPhysical,
#  emmo.SemioticEntity,
#  emmo.Semiotics,
#  emmo.Sign,
#  emmo.SignByReferent,
#  emmo.StandardizedPhysicalQuantity,
#  owl.Thing}

# %%
me.mammos_ontology.SpontaneousMagnetization.ancestors()
# Out:
# {emmo.CategorizedPhysicalQuantity,
#  emmo.CausalStructure,
#  emmo.Coded,
#  emmo.CodedByStructure,
#  emmo.Conventional,
#  emmo.EMMO,
#  emmo.ElectromagneticQuantity,
#  emmo.Fusion,
#  emmo.ISO80000Categorised,
#  emmo.Item,
#  emmo.Perspective,
#  emmo.PhysicalQuantity,
#  emmo.Property,
#  emmo.Quantity,
#  emmo.QuantityByPhysical,
#  emmo.Referent,
#  emmo.SemioticEntity,
#  emmo.Semiotics,
#  emmo.Sign,
#  emmo.SignByReferent,
#  magnetic_material_mammos.SpontaneousMagnetization,
#  owl.Thing}

# %%
me.M()
# Out:
# Entity(ontology_label='Magnetization', value=np.float64(0.0), unit='A / m')

# %%
me.mammos_ontology.sync_reasoner(reasoner="Pellet")
# Out:
# * Owlready2 * Running Pellet...
#     java -Xmx2000M -cp /home/swapneel/Projects/MaMMoS/mammos-entity/.pixi/envs/default/lib/python3.11/site-packages/owlready2/pellet/jena-tdb-0.10.0.jar:/home/swapneel/Projects/MaMMoS/mammos-entity/.pixi/envs/default/lib/python3.11/site-packages/owlready2/pellet/pellet-2.3.1.jar:/home/swapneel/Projects/MaMMoS/mammos-entity/.pixi/envs/default/lib/python3.11/site-packages/owlready2/pellet/log4j-api-2.19.0.jar:/home/swapneel/Projects/MaMMoS/mammos-entity/.pixi/envs/default/lib/python3.11/site-packages/owlready2/pellet/jgrapht-jdk1.5.jar:/home/swapneel/Projects/MaMMoS/mammos-entity/.pixi/envs/default/lib/python3.11/site-packages/owlready2/pellet/slf4j-log4j12-1.6.4.jar:/home/swapneel/Projects/MaMMoS/mammos-entity/.pixi/envs/default/lib/python3.11/site-packages/owlready2/pellet/xercesImpl-2.10.0.jar:/home/swapneel/Projects/MaMMoS/mammos-entity/.pixi/envs/default/lib/python3.11/site-packages/owlready2/pellet/log4j-1.2-api-2.19.0.jar:/home/swapneel/Projects/MaMMoS/mammos-entity/.pixi/envs/default/lib/python3.11/site-packages/owlready2/pellet/antlr-3.2.jar:/home/swapneel/Projects/MaMMoS/mammos-entity/.pixi/envs/default/lib/python3.11/site-packages/owlready2/pellet/log4j-core-2.19.0.jar:/home/swapneel/Projects/MaMMoS/mammos-entity/.pixi/envs/default/lib/python3.11/site-packages/owlready2/pellet/httpclient-4.2.3.jar:/home/swapneel/Projects/MaMMoS/mammos-entity/.pixi/envs/default/lib/python3.11/site-packages/owlready2/pellet/antlr-runtime-3.2.jar:/home/swapneel/Projects/MaMMoS/mammos-entity/.pixi/envs/default/lib/python3.11/site-packages/owlready2/pellet/aterm-java-1.6.jar:/home/swapneel/Projects/MaMMoS/mammos-entity/.pixi/envs/default/lib/python3.11/site-packages/owlready2/pellet/slf4j-api-1.6.4.jar:/home/swapneel/Projects/MaMMoS/mammos-entity/.pixi/envs/default/lib/python3.11/site-packages/owlready2/pellet/commons-codec-1.6.jar:/home/swapneel/Projects/MaMMoS/mammos-entity/.pixi/envs/default/lib/python3.11/site-packages/owlready2/pellet/owlapi-distribution-3.4.3-bin.jar:/home/swapneel/Projects/MaMMoS/mammos-entity/.pixi/envs/default/lib/python3.11/site-packages/owlready2/pellet/jena-arq-2.10.0.jar:/home/swapneel/Projects/MaMMoS/mammos-entity/.pixi/envs/default/lib/python3.11/site-packages/owlready2/pellet/httpcore-4.2.2.jar:/home/swapneel/Projects/MaMMoS/mammos-entity/.pixi/envs/default/lib/python3.11/site-packages/owlready2/pellet/xml-apis-1.4.01.jar:/home/swapneel/Projects/MaMMoS/mammos-entity/.pixi/envs/default/lib/python3.11/site-packages/owlready2/pellet/jena-core-2.10.0.jar:/home/swapneel/Projects/MaMMoS/mammos-entity/.pixi/envs/default/lib/python3.11/site-packages/owlready2/pellet/jena-iri-0.9.5.jar:/home/swapneel/Projects/MaMMoS/mammos-entity/.pixi/envs/default/lib/python3.11/site-packages/owlready2/pellet/jcl-over-slf4j-1.6.4.jar pellet.Pellet realize --loader Jena --input-format N-Triples --ignore-imports /tmp/tmp6w5cp5q2
# * Owlready2 * Pellet took 42.564932346343994 seconds
# * Owlready * Equivalenting: magnetic_material_mammos.CrystalStructure magnetic_material_mammos.MultilayerMagnet
# * Owlready * Equivalenting: magnetic_material_mammos.CrystalStructure magnetic_material_mammos.SpaceGroup
# * Owlready * Equivalenting: magnetic_material_mammos.CrystalStructure magnetic_material_mammos.GranularStructure
# * Owlready * Equivalenting: magnetic_material_mammos.CrystalStructure magnetic_material_mammos.CrystallineMagneticMaterial
# * Owlready * Equivalenting: magnetic_material_mammos.CrystalStructure magnetic_material_mammos.Grain
# * Owlready * Equivalenting: magnetic_material_mammos.CrystalStructure magnetic_material_mammos.StackingSquence
# * Owlready * Equivalenting: magnetic_material_mammos.CrystalStructure owl.Nothing
# * Owlready * Equivalenting: magnetic_material_mammos.MultilayerMagnet magnetic_material_mammos.CrystalStructure
# * Owlready * Equivalenting: magnetic_material_mammos.MultilayerMagnet magnetic_material_mammos.SpaceGroup
# * Owlready * Equivalenting: magnetic_material_mammos.MultilayerMagnet magnetic_material_mammos.GranularStructure
# * Owlready * Equivalenting: magnetic_material_mammos.MultilayerMagnet magnetic_material_mammos.CrystallineMagneticMaterial
# * Owlready * Equivalenting: magnetic_material_mammos.MultilayerMagnet magnetic_material_mammos.Grain
# * Owlready * Equivalenting: magnetic_material_mammos.MultilayerMagnet magnetic_material_mammos.StackingSquence
# * Owlready * Equivalenting: magnetic_material_mammos.MultilayerMagnet owl.Nothing
# * Owlready * Equivalenting: magnetic_material_mammos.SpaceGroup magnetic_material_mammos.CrystalStructure
# * Owlready * Equivalenting: magnetic_material_mammos.SpaceGroup magnetic_material_mammos.MultilayerMagnet
# * Owlready * Equivalenting: magnetic_material_mammos.SpaceGroup magnetic_material_mammos.GranularStructure
# * Owlready * Equivalenting: magnetic_material_mammos.SpaceGroup magnetic_material_mammos.CrystallineMagneticMaterial
# * Owlready * Equivalenting: magnetic_material_mammos.SpaceGroup magnetic_material_mammos.Grain
# * Owlready * Equivalenting: magnetic_material_mammos.SpaceGroup magnetic_material_mammos.StackingSquence
# * Owlready * Equivalenting: magnetic_material_mammos.SpaceGroup owl.Nothing
# * Owlready * Equivalenting: magnetic_material_mammos.GranularStructure magnetic_material_mammos.CrystalStructure
# * Owlready * Equivalenting: magnetic_material_mammos.GranularStructure magnetic_material_mammos.MultilayerMagnet
# * Owlready * Equivalenting: magnetic_material_mammos.GranularStructure magnetic_material_mammos.SpaceGroup
# * Owlready * Equivalenting: magnetic_material_mammos.GranularStructure magnetic_material_mammos.CrystallineMagneticMaterial
# * Owlready * Equivalenting: magnetic_material_mammos.GranularStructure magnetic_material_mammos.Grain
# * Owlready * Equivalenting: magnetic_material_mammos.GranularStructure magnetic_material_mammos.StackingSquence
# * Owlready * Equivalenting: magnetic_material_mammos.GranularStructure owl.Nothing
# * Owlready * Equivalenting: magnetic_material_mammos.CrystallineMagneticMaterial magnetic_material_mammos.CrystalStructure
# * Owlready * Equivalenting: magnetic_material_mammos.CrystallineMagneticMaterial magnetic_material_mammos.MultilayerMagnet
# * Owlready * Equivalenting: magnetic_material_mammos.CrystallineMagneticMaterial magnetic_material_mammos.SpaceGroup
# * Owlready * Equivalenting: magnetic_material_mammos.CrystallineMagneticMaterial magnetic_material_mammos.GranularStructure
# * Owlready * Equivalenting: magnetic_material_mammos.CrystallineMagneticMaterial magnetic_material_mammos.Grain
# * Owlready * Equivalenting: magnetic_material_mammos.CrystallineMagneticMaterial magnetic_material_mammos.StackingSquence
# * Owlready * Equivalenting: magnetic_material_mammos.CrystallineMagneticMaterial owl.Nothing
# * Owlready * Equivalenting: magnetic_material_mammos.Grain magnetic_material_mammos.CrystalStructure
# * Owlready * Equivalenting: magnetic_material_mammos.Grain magnetic_material_mammos.MultilayerMagnet
# * Owlready * Equivalenting: magnetic_material_mammos.Grain magnetic_material_mammos.SpaceGroup
# * Owlready * Equivalenting: magnetic_material_mammos.Grain magnetic_material_mammos.GranularStructure
# * Owlready * Equivalenting: magnetic_material_mammos.Grain magnetic_material_mammos.CrystallineMagneticMaterial
# * Owlready * Equivalenting: magnetic_material_mammos.Grain magnetic_material_mammos.StackingSquence
# * Owlready * Equivalenting: magnetic_material_mammos.Grain owl.Nothing
# * Owlready * Equivalenting: magnetic_material_mammos.StackingSquence magnetic_material_mammos.CrystalStructure
# * Owlready * Equivalenting: magnetic_material_mammos.StackingSquence magnetic_material_mammos.MultilayerMagnet
# * Owlready * Equivalenting: magnetic_material_mammos.StackingSquence magnetic_material_mammos.SpaceGroup
# * Owlready * Equivalenting: magnetic_material_mammos.StackingSquence magnetic_material_mammos.GranularStructure
# * Owlready * Equivalenting: magnetic_material_mammos.StackingSquence magnetic_material_mammos.CrystallineMagneticMaterial
# * Owlready * Equivalenting: magnetic_material_mammos.StackingSquence magnetic_material_mammos.Grain
# * Owlready * Equivalenting: magnetic_material_mammos.StackingSquence owl.Nothing
# * Owlready * Equivalenting: owl.Nothing magnetic_material_mammos.CrystalStructure
# * Owlready * Equivalenting: owl.Nothing magnetic_material_mammos.MultilayerMagnet
# * Owlready * Equivalenting: owl.Nothing magnetic_material_mammos.SpaceGroup
# * Owlready * Equivalenting: owl.Nothing magnetic_material_mammos.GranularStructure
# * Owlready * Equivalenting: owl.Nothing magnetic_material_mammos.CrystallineMagneticMaterial
# * Owlready * Equivalenting: owl.Nothing magnetic_material_mammos.Grain
# * Owlready * Equivalenting: owl.Nothing magnetic_material_mammos.StackingSquence
# * Owlready * Reparenting emmo.ChemicalEntity: {emmo.Matter} => {emmo.PhysicalObjectByBond, emmo.MatterByStructure}
# * Owlready * Reparenting emmo.MolecularEntity: {emmo.ParticulateMatter} => {emmo.ChemicalEntity, emmo.ParticulateMatter}
# * Owlready * Reparenting emmo.CarbonAtom: {emmo.Atom} => {emmo.Referent, emmo.Atom}
# * Owlready * Reparenting emmo.OsmiumAtom: {emmo.Atom} => {emmo.Referent, emmo.Atom}
# * Owlready * Reparenting emmo.GadoliniumAtom: {emmo.Atom} => {emmo.Referent, emmo.Atom}
# * Owlready * Reparenting emmo.CadmiumAtom: {emmo.Atom} => {emmo.Referent, emmo.Atom}
# * Owlready * Reparenting emmo.CuriumAtom: {emmo.Atom} => {emmo.Referent, emmo.Atom}
# * Owlready * Reparenting emmo.LutetiumAtom: {emmo.Atom} => {emmo.Referent, emmo.Atom}
# * Owlready * Reparenting emmo.GoldAtom: {emmo.Atom} => {emmo.Referent, emmo.Atom}
# * Owlready * Reparenting emmo.MolybdenumAtom: {emmo.Atom} => {emmo.Referent, emmo.Atom}
# * Owlready * Reparenting emmo.BismuthAtom: {emmo.Atom} => {emmo.Referent, emmo.Atom}
# * Owlready * Reparenting emmo.TitaniumAtom: {emmo.Atom} => {emmo.Referent, emmo.Atom}
# * Owlready * Reparenting emmo.PlatinumAtom: {emmo.Atom} => {emmo.Referent, emmo.Atom}
# * Owlready * Reparenting emmo.CeriumAtom: {emmo.Atom} => {emmo.Referent, emmo.Atom}
# * Owlready * Reparenting emmo.ErbiumAtom: {emmo.Atom} => {emmo.Referent, emmo.Atom}
# * Owlready * Reparenting emmo.NeptuniumAtom: {emmo.Atom} => {emmo.Referent, emmo.Atom}
# * Owlready * Reparenting emmo.AstatineAtom: {emmo.Atom} => {emmo.Referent, emmo.Atom}
# * Owlready * Reparenting emmo.PraseodymiumAtom: {emmo.Atom} => {emmo.Referent, emmo.Atom}
# * Owlready * Reparenting emmo.HassiumAtom: {emmo.Atom} => {emmo.Referent, emmo.Atom}
# * Owlready * Reparenting emmo.BariumAtom: {emmo.Atom} => {emmo.Referent, emmo.Atom}
# * Owlready * Reparenting emmo.NeonAtom: {emmo.Atom} => {emmo.Referent, emmo.Atom}
# * Owlready * Reparenting emmo.NitrogenAtom: {emmo.Atom} => {emmo.Referent, emmo.Atom}
# * Owlready * Reparenting emmo.FranciumAtom: {emmo.Atom} => {emmo.Referent, emmo.Atom}
# * Owlready * Reparenting emmo.ProtactiniumAtom: {emmo.Atom} => {emmo.Referent, emmo.Atom}
# * Owlready * Reparenting emmo.ChromiumAtom: {emmo.Atom} => {emmo.Referent, emmo.Atom}
# * Owlready * Reparenting emmo.CalciumAtom: {emmo.Atom} => {emmo.Referent, emmo.Atom}
# * Owlready * Reparenting emmo.ManganeseAtom: {emmo.Atom} => {emmo.Referent, emmo.Atom}
# * Owlready * Reparenting emmo.HeliumAtom: {emmo.Atom} => {emmo.Referent, emmo.Atom}
# * Owlready * Reparenting emmo.EinsteiniumAtom: {emmo.Atom} => {emmo.Referent, emmo.Atom}
# * Owlready * Reparenting emmo.NeodymiumAtom: {emmo.Atom} => {emmo.Referent, emmo.Atom}
# * Owlready * Reparenting emmo.NeutralAtom: {owl.Thing} => {emmo.StandaloneAtom}
# * Owlready * Reparenting emmo.IonAtom: {owl.Thing} => {emmo.StandaloneAtom}
# * Owlready * Reparenting emmo.MeitneriumAtom: {emmo.Atom} => {emmo.Referent, emmo.Atom}
# * Owlready * Reparenting emmo.SilverAtom: {emmo.Atom} => {emmo.Referent, emmo.Atom}
# * Owlready * Reparenting emmo.ActiniumAtom: {emmo.Atom} => {emmo.Referent, emmo.Atom}
# * Owlready * Reparenting emmo.LithiumAtom: {emmo.Atom} => {emmo.Referent, emmo.Atom}
# * Owlready * Reparenting emmo.RhodiumAtom: {emmo.Atom} => {emmo.Referent, emmo.Atom}
# * Owlready * Reparenting emmo.RadiumAtom: {emmo.Atom} => {emmo.Referent, emmo.Atom}
# * Owlready * Reparenting emmo.RoentgeniumAtom: {emmo.Atom} => {emmo.Referent, emmo.Atom}
# * Owlready * Reparenting emmo.CobaltAtom: {emmo.Atom} => {emmo.Referent, emmo.Atom}
# * Owlready * Reparenting emmo.ArsenicAtom: {emmo.Atom} => {emmo.Referent, emmo.Atom}
# * Owlready * Reparenting emmo.LawrenciumAtom: {emmo.Atom} => {emmo.Referent, emmo.Atom}
# * Owlready * Reparenting emmo.OxygenAtom: {emmo.Atom} => {emmo.Referent, emmo.Atom}
# * Owlready * Reparenting emmo.NobeliumAtom: {emmo.Atom} => {emmo.Referent, emmo.Atom}
# * Owlready * Reparenting emmo.IodineAtom: {emmo.Atom} => {emmo.Referent, emmo.Atom}
# * Owlready * Reparenting emmo.DarmastadtiumAtom: {emmo.Atom} => {emmo.Referent, emmo.Atom}
# * Owlready * Reparenting emmo.XenonAtom: {emmo.Atom} => {emmo.Referent, emmo.Atom}
# * Owlready * Reparenting emmo.CopperAtom: {emmo.Atom} => {emmo.Referent, emmo.Atom}
# * Owlready * Reparenting emmo.ThoriumAtom: {emmo.Atom} => {emmo.Referent, emmo.Atom}
# * Owlready * Reparenting emmo.HydrogenAtom: {emmo.Atom} => {emmo.Referent, emmo.Atom}
# * Owlready * Reparenting emmo.IridiumAtom: {emmo.Atom} => {emmo.Referent, emmo.Atom}
# * Owlready * Reparenting emmo.FermiumAtom: {emmo.Atom} => {emmo.Referent, emmo.Atom}
# * Owlready * Reparenting emmo.BoronAtom: {emmo.Atom} => {emmo.Referent, emmo.Atom}
# * Owlready * Reparenting emmo.SamariumAtom: {emmo.Atom} => {emmo.Referent, emmo.Atom}
# * Owlready * Reparenting emmo.BohriumAtom: {emmo.Atom} => {emmo.Referent, emmo.Atom}
# * Owlready * Reparenting emmo.SeaborgiumAtom: {emmo.Atom} => {emmo.Referent, emmo.Atom}
# * Owlready * Reparenting emmo.GermaniumAtom: {emmo.Atom} => {emmo.Referent, emmo.Atom}
# * Owlready * Reparenting emmo.PlutoniumAtom: {emmo.Atom} => {emmo.Referent, emmo.Atom}
# * Owlready * Reparenting emmo.TennessineAtom: {emmo.Atom} => {emmo.Referent, emmo.Atom}
# * Owlready * Reparenting emmo.GalliumAtom: {emmo.Atom} => {emmo.Referent, emmo.Atom}
# * Owlready * Reparenting emmo.KryptonAtom: {emmo.Atom} => {emmo.Referent, emmo.Atom}
# * Owlready * Reparenting emmo.YttriumAtom: {emmo.Atom} => {emmo.Referent, emmo.Atom}
# * Owlready * Reparenting emmo.PromethiumAtom: {emmo.Atom} => {emmo.Referent, emmo.Atom}
# * Owlready * Reparenting emmo.LeadAtom: {emmo.Atom} => {emmo.Referent, emmo.Atom}
# * Owlready * Reparenting emmo.ArgonAtom: {emmo.Atom} => {emmo.Referent, emmo.Atom}
# * Owlready * Reparenting emmo.NihoniumAtom: {emmo.Atom} => {emmo.Referent, emmo.Atom}
# * Owlready * Reparenting emmo.PoloniumAtom: {emmo.Atom} => {emmo.Referent, emmo.Atom}
# * Owlready * Reparenting emmo.RutherfordiumAtom: {emmo.Atom} => {emmo.Referent, emmo.Atom}
# * Owlready * Reparenting emmo.PhosphorusAtom: {emmo.Atom} => {emmo.Referent, emmo.Atom}
# * Owlready * Reparenting emmo.SiliconAtom: {emmo.Atom} => {emmo.Referent, emmo.Atom}
# * Owlready * Reparenting emmo.FleroviumAtom: {emmo.Atom} => {emmo.Referent, emmo.Atom}
# * Owlready * Reparenting emmo.TungstenAtom: {emmo.Atom} => {emmo.Referent, emmo.Atom}
# * Owlready * Reparenting emmo.AluminiumAtom: {emmo.Atom} => {emmo.Referent, emmo.Atom}
# * Owlready * Reparenting emmo.SeleniumAtom: {emmo.Atom} => {emmo.Referent, emmo.Atom}
# * Owlready * Reparenting emmo.ThuliumAtom: {emmo.Atom} => {emmo.Referent, emmo.Atom}
# * Owlready * Reparenting emmo.CaesiumAtom: {emmo.Atom} => {emmo.Referent, emmo.Atom}
# * Owlready * Reparenting emmo.SulfurAtom: {emmo.Atom} => {emmo.Referent, emmo.Atom}
# * Owlready * Reparenting emmo.EuropiumAtom: {emmo.Atom} => {emmo.Referent, emmo.Atom}
# * Owlready * Reparenting emmo.YtterbiumAtom: {emmo.Atom} => {emmo.Referent, emmo.Atom}
# * Owlready * Reparenting emmo.RheniumAtom: {emmo.Atom} => {emmo.Referent, emmo.Atom}
# * Owlready * Reparenting emmo.StrontiumAtom: {emmo.Atom} => {emmo.Referent, emmo.Atom}
# * Owlready * Reparenting emmo.RutheniumAtom: {emmo.Atom} => {emmo.Referent, emmo.Atom}
# * Owlready * Reparenting emmo.IndiumAtom: {emmo.Atom} => {emmo.Referent, emmo.Atom}
# * Owlready * Reparenting emmo.TinAtom: {emmo.Atom} => {emmo.Referent, emmo.Atom}
# * Owlready * Reparenting emmo.TechnetiumAtom: {emmo.Atom} => {emmo.Referent, emmo.Atom}
# * Owlready * Reparenting emmo.IronAtom: {emmo.Atom} => {emmo.Referent, emmo.Atom}
# * Owlready * Reparenting emmo.NiobiumAtom: {emmo.Atom} => {emmo.Referent, emmo.Atom}
# * Owlready * Reparenting emmo.LanthanumAtom: {emmo.Atom} => {emmo.Referent, emmo.Atom}
# * Owlready * Reparenting emmo.UraniumAtom: {emmo.Atom} => {emmo.Referent, emmo.Atom}
# * Owlready * Reparenting emmo.BromineAtom: {emmo.Atom} => {emmo.Referent, emmo.Atom}
# * Owlready * Reparenting emmo.CaliforniumAtom: {emmo.Atom} => {emmo.Referent, emmo.Atom}
# * Owlready * Reparenting emmo.MoscoviumAtom: {emmo.Atom} => {emmo.Referent, emmo.Atom}
# * Owlready * Reparenting emmo.DubniumAtom: {emmo.Atom} => {emmo.Referent, emmo.Atom}
# * Owlready * Reparenting emmo.BerylliumAtom: {emmo.Atom} => {emmo.Referent, emmo.Atom}
# * Owlready * Reparenting emmo.ChlorineAtom: {emmo.Atom} => {emmo.Referent, emmo.Atom}
# * Owlready * Reparenting emmo.MercuryAtom: {emmo.Atom} => {emmo.Referent, emmo.Atom}
# * Owlready * Reparenting emmo.ThalliumAtom: {emmo.Atom} => {emmo.Referent, emmo.Atom}
# * Owlready * Reparenting emmo.ZirconiumAtom: {emmo.Atom} => {emmo.Referent, emmo.Atom}
# * Owlready * Reparenting emmo.TelluriumAtom: {emmo.Atom} => {emmo.Referent, emmo.Atom}
# * Owlready * Reparenting emmo.AntimonyAtom: {emmo.Atom} => {emmo.Referent, emmo.Atom}
# * Owlready * Reparenting emmo.RubidiumAtom: {emmo.Atom} => {emmo.Referent, emmo.Atom}
# * Owlready * Reparenting emmo.NickelAtom: {emmo.Atom} => {emmo.Referent, emmo.Atom}
# * Owlready * Reparenting emmo.PalladiumAtom: {emmo.Atom} => {emmo.Referent, emmo.Atom}
# * Owlready * Reparenting emmo.OganessonAtom: {emmo.Atom} => {emmo.Referent, emmo.Atom}
# * Owlready * Reparenting emmo.BerkeliumAtom: {emmo.Atom} => {emmo.Referent, emmo.Atom}
# * Owlready * Reparenting emmo.PotassiumAtom: {emmo.Atom} => {emmo.Referent, emmo.Atom}
# * Owlready * Reparenting emmo.TantalumAtom: {emmo.Atom} => {emmo.Referent, emmo.Atom}
# * Owlready * Reparenting emmo.SodiumAtom: {emmo.Atom} => {emmo.Referent, emmo.Atom}
# * Owlready * Reparenting emmo.DysprosiumAtom: {emmo.Atom} => {emmo.Referent, emmo.Atom}
# * Owlready * Reparenting emmo.HafniumAtom: {emmo.Atom} => {emmo.Referent, emmo.Atom}
# * Owlready * Reparenting emmo.TerbiumAtom: {emmo.Atom} => {emmo.Referent, emmo.Atom}
# * Owlready * Reparenting emmo.MendeleviumAtom: {emmo.Atom} => {emmo.Referent, emmo.Atom}
# * Owlready * Reparenting emmo.VanadiumAtom: {emmo.Atom} => {emmo.Referent, emmo.Atom}
# * Owlready * Reparenting emmo.LivermoriumAtom: {emmo.Atom} => {emmo.Referent, emmo.Atom}
# * Owlready * Reparenting emmo.ZincAtom: {emmo.Atom} => {emmo.Referent, emmo.Atom}
# * Owlready * Reparenting emmo.AmericiumAtom: {emmo.Atom} => {emmo.Referent, emmo.Atom}
# * Owlready * Reparenting emmo.CoperniciumAtom: {emmo.Atom} => {emmo.Referent, emmo.Atom}
# * Owlready * Reparenting emmo.ScandiumAtom: {emmo.Atom} => {emmo.Referent, emmo.Atom}
# * Owlready * Reparenting emmo.HolmiumAtom: {emmo.Atom} => {emmo.Referent, emmo.Atom}
# * Owlready * Reparenting emmo.RadonAtom: {emmo.Atom} => {emmo.Referent, emmo.Atom}
# * Owlready * Reparenting emmo.FluorineAtom: {emmo.Atom} => {emmo.Referent, emmo.Atom}
# * Owlready * Reparenting emmo.MagnesiumAtom: {emmo.Atom} => {emmo.Referent, emmo.Atom}
# * Owlready * Reparenting emmo.ChemicalSubstance: {emmo.Substance} => {emmo.ChemicalEntity, emmo.Substance}
# * Owlready * Reparenting emmo.InorganicCompound: {owl.Thing} => {emmo.ChemicalCompound}
# * Owlready * Reparenting emmo.OrganicCompound: {owl.Thing} => {emmo.ChemicalCompound}
# * Owlready * Reparenting magnetic_material_mammos.MagneticMaterial: {emmo.MaterialByStructure} => {emmo.MaterialByStructure, emmo.Referent}
# * Owlready * Reparenting magnetic_material_mammos.Magnet: {emmo.FunctionallyDefinedMaterial} => {emmo.Referent, emmo.FunctionallyDefinedMaterial}
# * Owlready * Reparenting emmo.ManufacturedMaterial: {owl.Thing} => {emmo.ManufacturedProduct, emmo.Material}
# * Owlready * Reparenting magnetic_material_mammos.SpacerLayer: {emmo.Material} => {emmo.Referent, emmo.Material}
# * Owlready * Reparenting magnetic_material_mammos.NonMagneticMaterial: {emmo.Material} => {emmo.Referent, emmo.Material}
# * Owlready * Reparenting magnetic_material_mammos.SecondaryPhase: {emmo.PhaseOfMatter, emmo.Material} => {emmo.PhaseOfMatter, emmo.Referent, emmo.Material}
# * Owlready * Reparenting emmo.LiquidGasSuspension: {emmo.Liquid} => {emmo.Suspension, emmo.Liquid}
# * Owlready * Reparenting emmo.LiquidLiquidSuspension: {emmo.Liquid} => {emmo.Suspension, emmo.Liquid}
# * Owlready * Reparenting emmo.LiquidSolidSuspension: {emmo.Liquid} => {emmo.Suspension, emmo.Liquid}
# * Owlready * Reparenting emmo.Solid: {emmo.CondensedMatter, emmo.ContinuumSubstance} => {emmo.CondensedMatter}
# * Owlready * Reparenting emmo.SolidMixture: {owl.Thing} => {emmo.Mixture, emmo.Solid}
# * Owlready * Reparenting emmo.SolidSolidSuspension: {emmo.Solid} => {emmo.SolidMixture, emmo.Suspension}
# * Owlready * Reparenting emmo.SolidLiquidSuspension: {emmo.Solid} => {emmo.SolidMixture, emmo.Suspension}
# * Owlready * Reparenting emmo.Gel: {emmo.Colloid, emmo.Solid} => {emmo.Colloid, emmo.SolidMixture}
# * Owlready * Reparenting emmo.SolidSol: {emmo.Sol, emmo.Solid} => {emmo.Sol, emmo.SolidMixture}
# * Owlready * Reparenting emmo.SolidSolution: {emmo.Solution, emmo.Solid} => {emmo.Solution, emmo.SolidMixture}
# * Owlready * Reparenting emmo.SolidFoam: {emmo.Foam, emmo.Solid} => {emmo.SolidMixture, emmo.Foam}
# * Owlready * Reparenting emmo.SolidGasSuspension: {emmo.Solid} => {emmo.SolidMixture, emmo.Suspension}
# * Owlready * Reparenting emmo.Suspension: {emmo.PhaseHeterogeneousMixture} => {emmo.Dispersion, emmo.StateOfMatter, emmo.PhaseHeterogeneousMixture}
# * Owlready * Reparenting emmo.GasSolidSuspension: {emmo.Gas} => {emmo.GasMixture, emmo.Suspension}
# * Owlready * Reparenting emmo.GasLiquidSuspension: {emmo.Gas} => {emmo.GasMixture, emmo.Suspension}
# * Owlready * Reparenting emmo.Fluid: {emmo.StateOfMatter, emmo.ContinuumSubstance} => {emmo.StateOfMatter}
# * Owlready * Reparenting emmo.GasMixture: {owl.Thing} => {emmo.Mixture, emmo.Gas}
# * Owlready * Reparenting emmo.Aerosol: {emmo.Colloid, emmo.Gas} => {emmo.GasMixture, emmo.Colloid}
# * Owlready * Reparenting emmo.GasSolution: {owl.Thing} => {emmo.Solution, emmo.GasMixture}
# * Owlready * Reparenting emmo.Dispersion: {owl.Thing} => {emmo.Mixture}
# * Owlready * Reparenting emmo.Solution: {emmo.PhaseHomogeneousMixture} => {emmo.Dispersion, emmo.PhaseHomogeneousMixture}
# * Owlready * Reparenting emmo.Colloid: {emmo.PhaseHeterogeneousMixture} => {emmo.Dispersion, emmo.PhaseHeterogeneousMixture}
# * Owlready * Reparenting emmo.CompositeBoson: {owl.Thing} => {emmo.Boson, emmo.BondedParticle}
# * Owlready * Reparenting emmo.CompositeFermion: {owl.Thing} => {emmo.Fermion, emmo.BondedParticle}
# * Owlready * Reparenting emmo.PhysicsBasedModel: {emmo.MathematicalModel} => {emmo.MathematicalModel, emmo.CausalSystem}
# * Owlready * Reparenting emmo.ContinuumModel: {owl.Thing} => {emmo.MaterialsModel}
# * Owlready * Reparenting emmo.MesoscopicModel: {owl.Thing} => {emmo.MaterialsModel}
# * Owlready * Reparenting emmo.ElectronicModel: {owl.Thing} => {emmo.MaterialsModel}
# * Owlready * Reparenting emmo.AtomisticModel: {owl.Thing} => {emmo.MaterialsModel}
# * Owlready * Reparenting emmo.Equation: {emmo.MathematicalFormula, emmo.Mathematical} => {emmo.MathematicalFormula, emmo.CausalSystem}
# * Owlready * Reparenting emmo.Agent: {emmo.Participant} => {emmo.Participant, emmo.QRole}
# * Owlready * Reparenting emmo.Task: {emmo.Procedure} => {emmo.Procedure, emmo.Role}
# * Owlready * Reparenting emmo.DeepDrawing: {emmo.ReshapeManufacturing, emmo.TensileForming} => {emmo.TensileForming}
# * Owlready * Reparenting emmo.Measurement: {emmo.Observation, emmo.Procedure} => {emmo.Observation, emmo.Procedure, emmo.Object}
# * Owlready * Reparenting emmo.Vector: {emmo.Array} => {emmo.SpatioTemporalTessellation, emmo.Array}
# * Owlready * Reparenting emmo.Velocity: {emmo.ISQDerivedQuantity, emmo.SpaceAndTimeQuantity, emmo.Vector, emmo.Intensive} => {emmo.Information, emmo.ISQDerivedQuantity, emmo.Vector, emmo.SpaceAndTimeQuantity, emmo.Intensive}
# * Owlready * Reparenting emmo.PositionVector: {emmo.ISQDerivedQuantity, emmo.Vector} => {emmo.ISQDerivedQuantity, emmo.Vector, emmo.Information}
# * Owlready * Reparenting magnetic_material_mammos.XRDTwoThetaAngles: {emmo.Vector} => {emmo.PhysicalQuantity, emmo.Vector, emmo.Information}
# * Owlready * Reparenting magnetic_material_mammos.XRDCounts: {emmo.Vector} => {emmo.PhysicalQuantity, emmo.Vector, emmo.Information}
# * Owlready * Reparenting emmo.MeasurementResult: {emmo.Objective} => {emmo.SpatioTemporalTessellation, emmo.Objective}
# * Owlready * Reparenting emmo.Matrix: {emmo.Array} => {emmo.SpatioTemporalTessellation, emmo.Array}
# * Owlready * Reparenting magnetic_material_mammos.XrayDiffractionData: {emmo.Property, emmo.Matrix} => {emmo.Referent, emmo.Matrix, emmo.Information, emmo.Property}
# * Owlready * Reparenting emmo.Array3D: {emmo.Array} => {emmo.SpatioTemporalTessellation, emmo.Array}
# * Owlready * Reparenting emmo.ChemicalComposition: {emmo.Chemical, emmo.SymbolicConstruct} => {emmo.SpatioTemporalTessellation, emmo.ChemicalSymbolicConstruct}
# * Owlready * Reparenting emmo.TotalComposition: {owl.Thing} => {emmo.ChemicalComposition}
# * Owlready * Reparenting emmo.SingleComponentComposition: {owl.Thing} => {emmo.ChemicalComposition}
# * Owlready * Reparenting emmo.PartialComposition: {owl.Thing} => {emmo.ChemicalComposition}
# * Owlready * Reparenting emmo.ChemicalFormula: {emmo.Chemical} => {emmo.ChemicalSpecies, emmo.SpatioTemporalTessellation}
# * Owlready * Reparenting emmo.PrefixedUnit: {emmo.MeasurementUnitByPrefix} => {emmo.SpatioTemporalTessellation, emmo.MeasurementUnitByPrefix}
# * Owlready * Reparenting emmo.SIAcceptedPrefixedUnit: {emmo.PrefixedUnit} => {emmo.PrefixedUnit, emmo.SIAccepted}
# * Owlready * Reparenting emmo.SIMetricPrefixedUnit: {emmo.MetricPrefixedUnit} => {emmo.MetricPrefixedUnit, emmo.SINonCoherentUnit}
# * Owlready * Reparenting emmo.AttoCoulomb: {emmo.ElectricChargeUnit, emmo.AttoPrefixedUnit, emmo.SINonCoherentUnit, emmo.PrefixedUnit} => {emmo.ElectricChargeUnit, emmo.AttoPrefixedUnit, emmo.SIMetricPrefixedUnit}
# * Owlready * Reparenting emmo.AttoFarad: {emmo.PrefixedUnit, emmo.AttoPrefixedUnit, emmo.SINonCoherentUnit, emmo.CapacitanceUnit} => {emmo.AttoPrefixedUnit, emmo.SIMetricPrefixedUnit, emmo.CapacitanceUnit}
# * Owlready * Reparenting emmo.AttoJouleSecond: {emmo.PrefixedUnit, emmo.AttoPrefixedUnit, emmo.SINonCoherentUnit, emmo.AngularMomentumUnit} => {emmo.AttoPrefixedUnit, emmo.SIMetricPrefixedUnit, emmo.AngularMomentumUnit}
# * Owlready * Reparenting emmo.AttoJoule: {emmo.PrefixedUnit, emmo.AttoPrefixedUnit, emmo.SINonCoherentUnit, emmo.EnergyUnit} => {emmo.EnergyUnit, emmo.AttoPrefixedUnit, emmo.SIMetricPrefixedUnit}
# * Owlready * Reparenting emmo.CentiCoulomb: {emmo.ElectricChargeUnit, emmo.CentiPrefixedUnit, emmo.SINonCoherentUnit, emmo.PrefixedUnit} => {emmo.ElectricChargeUnit, emmo.CentiPrefixedUnit, emmo.SIMetricPrefixedUnit}
# * Owlready * Reparenting emmo.CentiGram: {emmo.PrefixedUnit, emmo.CentiPrefixedUnit, emmo.SINonCoherentUnit, emmo.MassUnit} => {emmo.CentiPrefixedUnit, emmo.SIMetricPrefixedUnit, emmo.MassUnit}
# * Owlready * Reparenting emmo.CentiMetrePerKelvin: {emmo.PrefixedUnit, emmo.CentiPrefixedUnit, emmo.SINonCoherentUnit, emmo.LengthPerTemperatureUnit} => {emmo.CentiPrefixedUnit, emmo.SIMetricPrefixedUnit, emmo.LengthPerTemperatureUnit}
# * Owlready * Reparenting emmo.CentiMetrePerSecond: {emmo.PrefixedUnit, emmo.SpeedUnit, emmo.SINonCoherentUnit, emmo.CentiPrefixedUnit} => {emmo.CentiPrefixedUnit, emmo.SIMetricPrefixedUnit, emmo.SpeedUnit}
# * Owlready * Reparenting emmo.CentiMetrePerSquareSecond: {emmo.PrefixedUnit, emmo.CentiPrefixedUnit, emmo.SINonCoherentUnit, emmo.AccelerationUnit} => {emmo.CentiPrefixedUnit, emmo.SIMetricPrefixedUnit, emmo.AccelerationUnit}
# * Owlready * Reparenting emmo.CentiMetre: {emmo.PrefixedUnit, emmo.CentiPrefixedUnit, emmo.SINonCoherentUnit, emmo.LengthUnit} => {emmo.CentiPrefixedUnit, emmo.SIMetricPrefixedUnit, emmo.LengthUnit}
# * Owlready * Reparenting emmo.CentiMolePerKilogram: {emmo.AmountPerMassUnit, emmo.CentiPrefixedUnit, emmo.SINonCoherentUnit, emmo.PrefixedUnit} => {emmo.AmountPerMassUnit, emmo.CentiPrefixedUnit, emmo.SIMetricPrefixedUnit}
# * Owlready * Reparenting emmo.CentiMole: {emmo.PrefixedUnit, emmo.CentiPrefixedUnit, emmo.SINonCoherentUnit, emmo.AmountUnit} => {emmo.CentiPrefixedUnit, emmo.SIMetricPrefixedUnit, emmo.AmountUnit}
# * Owlready * Reparenting emmo.CentiNewtonMetre: {emmo.PrefixedUnit, emmo.CentiPrefixedUnit, emmo.SINonCoherentUnit, emmo.EnergyUnit} => {emmo.EnergyUnit, emmo.CentiPrefixedUnit, emmo.SIMetricPrefixedUnit}
# * Owlready * Reparenting emmo.CentiNewton: {emmo.ForceUnit, emmo.CentiPrefixedUnit, emmo.SINonCoherentUnit, emmo.PrefixedUnit} => {emmo.ForceUnit, emmo.CentiPrefixedUnit, emmo.SIMetricPrefixedUnit}
# * Owlready * Reparenting emmo.DecaCoulomb: {emmo.ElectricChargeUnit, emmo.SINonCoherentUnit, emmo.DecaPrefixedUnit, emmo.PrefixedUnit} => {emmo.ElectricChargeUnit, emmo.SIMetricPrefixedUnit, emmo.DecaPrefixedUnit}
# * Owlready * Reparenting emmo.DecaGram: {emmo.PrefixedUnit, emmo.MassUnit, emmo.SINonCoherentUnit, emmo.DecaPrefixedUnit} => {emmo.DecaPrefixedUnit, emmo.SIMetricPrefixedUnit, emmo.MassUnit}
# * Owlready * Reparenting emmo.DecaMetre: {emmo.PrefixedUnit, emmo.SINonCoherentUnit, emmo.DecaPrefixedUnit, emmo.LengthUnit} => {emmo.SIMetricPrefixedUnit, emmo.DecaPrefixedUnit, emmo.LengthUnit}
# * Owlready * Reparenting emmo.DecaPascal: {emmo.PrefixedUnit, emmo.SINonCoherentUnit, emmo.DecaPrefixedUnit, emmo.PressureUnit} => {emmo.SIMetricPrefixedUnit, emmo.DecaPrefixedUnit, emmo.PressureUnit}
# * Owlready * Reparenting emmo.DeciBel: {emmo.LogarithmicUnit, emmo.DeciPrefixedUnit, emmo.SINonCoherentUnit, emmo.PrefixedUnit} => {emmo.DeciPrefixedUnit, emmo.LogarithmicUnit, emmo.SIMetricPrefixedUnit}
# * Owlready * Reparenting emmo.DeciCoulomb: {emmo.ElectricChargeUnit, emmo.DeciPrefixedUnit, emmo.SINonCoherentUnit, emmo.PrefixedUnit} => {emmo.ElectricChargeUnit, emmo.DeciPrefixedUnit, emmo.SIMetricPrefixedUnit}
# * Owlready * Reparenting emmo.DeciGram: {emmo.PrefixedUnit, emmo.DeciPrefixedUnit, emmo.SINonCoherentUnit, emmo.MassUnit} => {emmo.DeciPrefixedUnit, emmo.SIMetricPrefixedUnit, emmo.MassUnit}
# * Owlready * Reparenting emmo.DeciMetre: {emmo.PrefixedUnit, emmo.DeciPrefixedUnit, emmo.SINonCoherentUnit, emmo.LengthUnit} => {emmo.DeciPrefixedUnit, emmo.SIMetricPrefixedUnit, emmo.LengthUnit}
# * Owlready * Reparenting emmo.DeciNewtonMetre: {emmo.PrefixedUnit, emmo.DeciPrefixedUnit, emmo.EnergyUnit, emmo.SINonCoherentUnit} => {emmo.EnergyUnit, emmo.DeciPrefixedUnit, emmo.SIMetricPrefixedUnit}
# * Owlready * Reparenting emmo.DeciNewton: {emmo.ForceUnit, emmo.DeciPrefixedUnit, emmo.SINonCoherentUnit, emmo.PrefixedUnit} => {emmo.ForceUnit, emmo.DeciPrefixedUnit, emmo.SIMetricPrefixedUnit}
# * Owlready * Reparenting emmo.DeciSiemensPerMetre: {emmo.PrefixedUnit, emmo.DeciPrefixedUnit, emmo.SINonCoherentUnit, emmo.ElectricConductivityUnit} => {emmo.DeciPrefixedUnit, emmo.SIMetricPrefixedUnit, emmo.ElectricConductivityUnit}
# * Owlready * Reparenting emmo.DeciSiemens: {emmo.PrefixedUnit, emmo.DeciPrefixedUnit, emmo.SINonCoherentUnit, emmo.ElectricConductanceUnit} => {emmo.DeciPrefixedUnit, emmo.SIMetricPrefixedUnit, emmo.ElectricConductanceUnit}
# * Owlready * Reparenting emmo.ExaCoulomb: {emmo.ElectricChargeUnit, emmo.ExaPrefixedUnit, emmo.SINonCoherentUnit, emmo.PrefixedUnit} => {emmo.ElectricChargeUnit, emmo.ExaPrefixedUnit, emmo.SIMetricPrefixedUnit}
# * Owlready * Reparenting emmo.ExaJoule: {emmo.PrefixedUnit, emmo.ExaPrefixedUnit, emmo.SINonCoherentUnit, emmo.EnergyUnit} => {emmo.EnergyUnit, emmo.ExaPrefixedUnit, emmo.SIMetricPrefixedUnit}
# * Owlready * Reparenting emmo.FemtoCoulomb: {emmo.FemtoPrefixedUnit, emmo.SINonCoherentUnit, emmo.ElectricChargeUnit, emmo.PrefixedUnit} => {emmo.FemtoPrefixedUnit, emmo.SIMetricPrefixedUnit, emmo.ElectricChargeUnit}
# * Owlready * Reparenting emmo.FemtoGramPerKilogram: {emmo.FemtoPrefixedUnit, emmo.SINonCoherentUnit, emmo.MassFractionUnit, emmo.PrefixedUnit} => {emmo.FemtoPrefixedUnit, emmo.SIMetricPrefixedUnit, emmo.MassFractionUnit}
# * Owlready * Reparenting emmo.FemtoGram: {emmo.FemtoPrefixedUnit, emmo.SINonCoherentUnit, emmo.MassUnit, emmo.PrefixedUnit} => {emmo.FemtoPrefixedUnit, emmo.SIMetricPrefixedUnit, emmo.MassUnit}
# * Owlready * Reparenting emmo.FemtoJoule: {emmo.FemtoPrefixedUnit, emmo.EnergyUnit, emmo.SINonCoherentUnit, emmo.PrefixedUnit} => {emmo.FemtoPrefixedUnit, emmo.SIMetricPrefixedUnit, emmo.EnergyUnit}
# * Owlready * Reparenting emmo.FemtoMetre: {emmo.FemtoPrefixedUnit, emmo.SINonCoherentUnit, emmo.PrefixedUnit, emmo.LengthUnit} => {emmo.FemtoPrefixedUnit, emmo.SIMetricPrefixedUnit, emmo.LengthUnit}
# * Owlready * Reparenting emmo.FemtoMolePerKilogram: {emmo.FemtoPrefixedUnit, emmo.SINonCoherentUnit, emmo.AmountPerMassUnit, emmo.PrefixedUnit} => {emmo.FemtoPrefixedUnit, emmo.SIMetricPrefixedUnit, emmo.AmountPerMassUnit}
# * Owlready * Reparenting emmo.FemtoMole: {emmo.FemtoPrefixedUnit, emmo.SINonCoherentUnit, emmo.AmountUnit, emmo.PrefixedUnit} => {emmo.FemtoPrefixedUnit, emmo.SIMetricPrefixedUnit, emmo.AmountUnit}
# * Owlready * Reparenting emmo.GigaBecquerel: {emmo.PrefixedUnit, emmo.GigaPrefixedUnit, emmo.SINonCoherentUnit, emmo.FrequencyUnit} => {emmo.GigaPrefixedUnit, emmo.SIMetricPrefixedUnit, emmo.FrequencyUnit}
# * Owlready * Reparenting emmo.GigaCoulombPerCubicMetre: {emmo.PrefixedUnit, emmo.SpeedUnit, emmo.SINonCoherentUnit, emmo.GigaPrefixedUnit} => {emmo.GigaPrefixedUnit, emmo.SIMetricPrefixedUnit, emmo.SpeedUnit}
# * Owlready * Reparenting emmo.GigaCoulomb: {emmo.ElectricChargeUnit, emmo.GigaPrefixedUnit, emmo.SINonCoherentUnit, emmo.PrefixedUnit} => {emmo.ElectricChargeUnit, emmo.GigaPrefixedUnit, emmo.SIMetricPrefixedUnit}
# * Owlready * Reparenting emmo.GigaHertzMetre: {emmo.PrefixedUnit, emmo.SpeedUnit, emmo.SINonCoherentUnit, emmo.GigaPrefixedUnit} => {emmo.GigaPrefixedUnit, emmo.SIMetricPrefixedUnit, emmo.SpeedUnit}
# * Owlready * Reparenting emmo.GigaHertz: {emmo.PrefixedUnit, emmo.GigaPrefixedUnit, emmo.SINonCoherentUnit, emmo.FrequencyUnit} => {emmo.GigaPrefixedUnit, emmo.SIMetricPrefixedUnit, emmo.FrequencyUnit}
# * Owlready * Reparenting emmo.GigaJoule: {emmo.PrefixedUnit, emmo.GigaPrefixedUnit, emmo.SINonCoherentUnit, emmo.EnergyUnit} => {emmo.EnergyUnit, emmo.GigaPrefixedUnit, emmo.SIMetricPrefixedUnit}
# * Owlready * Reparenting emmo.GigaOhm: {emmo.PrefixedUnit, emmo.ElectricResistanceUnit, emmo.GigaPrefixedUnit, emmo.SINonCoherentUnit} => {emmo.ElectricResistanceUnit, emmo.GigaPrefixedUnit, emmo.SIMetricPrefixedUnit}
# * Owlready * Reparenting emmo.GigaPascal: {emmo.PrefixedUnit, emmo.GigaPrefixedUnit, emmo.SINonCoherentUnit, emmo.PressureUnit} => {emmo.GigaPrefixedUnit, emmo.SIMetricPrefixedUnit, emmo.PressureUnit}
# * Owlready * Reparenting emmo.GigaWatt: {emmo.PrefixedUnit, emmo.GigaPrefixedUnit, emmo.SINonCoherentUnit, emmo.PowerUnit} => {emmo.GigaPrefixedUnit, emmo.SIMetricPrefixedUnit, emmo.PowerUnit}
# * Owlready * Reparenting emmo.GramMilliMetre: {emmo.PrefixedUnit, emmo.MeasurementUnit, emmo.SINonCoherentUnit, emmo.LengthMassUnit} => {emmo.SIMetricPrefixedUnit, emmo.LengthMassUnit}
# * Owlready * Reparenting emmo.GramPerCubicCentiMetre: {emmo.PrefixedUnit, emmo.DensityUnit, emmo.SINonCoherentUnit, emmo.MeasurementUnit} => {emmo.DensityUnit, emmo.SIMetricPrefixedUnit}
# * Owlready * Reparenting emmo.GramPerCubicDeciMetre: {emmo.PrefixedUnit, emmo.DensityUnit, emmo.SINonCoherentUnit, emmo.MeasurementUnit} => {emmo.DensityUnit, emmo.SIMetricPrefixedUnit}
# * Owlready * Reparenting emmo.GramPerKiloMetre: {emmo.PrefixedUnit, emmo.SINonCoherentUnit, emmo.MassPerLengthUnit, emmo.MeasurementUnit} => {emmo.SIMetricPrefixedUnit, emmo.MassPerLengthUnit}
# * Owlready * Reparenting emmo.GramPerMilliMetre: {emmo.PrefixedUnit, emmo.SINonCoherentUnit, emmo.MassPerLengthUnit, emmo.MeasurementUnit} => {emmo.SIMetricPrefixedUnit, emmo.MassPerLengthUnit}
# * Owlready * Reparenting emmo.GramPerSquareCentiMetre: {emmo.PrefixedUnit, emmo.SINonCoherentUnit, emmo.AreaDensityUnit, emmo.MeasurementUnit} => {emmo.SIMetricPrefixedUnit, emmo.AreaDensityUnit}
# * Owlready * Reparenting emmo.HectoCoulomb: {emmo.ElectricChargeUnit, emmo.SINonCoherentUnit, emmo.HectoPrefixedUnit, emmo.PrefixedUnit} => {emmo.ElectricChargeUnit, emmo.SIMetricPrefixedUnit, emmo.HectoPrefixedUnit}
# * Owlready * Reparenting emmo.HectoGram: {emmo.PrefixedUnit, emmo.SINonCoherentUnit, emmo.MassUnit, emmo.HectoPrefixedUnit} => {emmo.SIMetricPrefixedUnit, emmo.MassUnit, emmo.HectoPrefixedUnit}
# * Owlready * Reparenting emmo.HectoMetre: {emmo.PrefixedUnit, emmo.SINonCoherentUnit, emmo.HectoPrefixedUnit, emmo.LengthUnit} => {emmo.SIMetricPrefixedUnit, emmo.HectoPrefixedUnit, emmo.LengthUnit}
# * Owlready * Reparenting emmo.HectoPascalCubicMetrePerSecond: {emmo.PrefixedUnit, emmo.PowerAreaUnit, emmo.SINonCoherentUnit, emmo.HectoPrefixedUnit} => {emmo.PowerAreaUnit, emmo.SIMetricPrefixedUnit, emmo.HectoPrefixedUnit}
# * Owlready * Reparenting emmo.HectoPascalPerKelvin: {emmo.PrefixedUnit, emmo.SINonCoherentUnit, emmo.HectoPrefixedUnit, emmo.PressurePerTemperatureUnit} => {emmo.SIMetricPrefixedUnit, emmo.HectoPrefixedUnit, emmo.PressurePerTemperatureUnit}
# * Owlready * Reparenting emmo.HectoPascal: {emmo.PrefixedUnit, emmo.SINonCoherentUnit, emmo.HectoPrefixedUnit, emmo.PressureUnit} => {emmo.SIMetricPrefixedUnit, emmo.HectoPrefixedUnit, emmo.PressureUnit}
# * Owlready * Reparenting emmo.KiloAmperePerMetre: {emmo.PrefixedUnit, emmo.MagneticFieldStrengthUnit, emmo.SINonCoherentUnit, emmo.KiloPrefixedUnit} => {emmo.KiloPrefixedUnit, emmo.SIMetricPrefixedUnit, emmo.MagneticFieldStrengthUnit}
# * Owlready * Reparenting emmo.KiloAmperePerSquareMetre: {emmo.KiloPrefixedUnit, emmo.SINonCoherentUnit, emmo.ElectricCurrentDensityUnit, emmo.PrefixedUnit} => {emmo.KiloPrefixedUnit, emmo.SIMetricPrefixedUnit, emmo.ElectricCurrentDensityUnit}
# * Owlready * Reparenting emmo.KiloAmpere: {emmo.PrefixedUnit, emmo.ElectricCurrentUnit, emmo.SINonCoherentUnit, emmo.KiloPrefixedUnit} => {emmo.ElectricCurrentUnit, emmo.SIMetricPrefixedUnit, emmo.KiloPrefixedUnit}
# * Owlready * Reparenting emmo.KiloBecquerel: {emmo.KiloPrefixedUnit, emmo.SINonCoherentUnit, emmo.FrequencyUnit, emmo.PrefixedUnit} => {emmo.SIMetricPrefixedUnit, emmo.KiloPrefixedUnit, emmo.FrequencyUnit}
# * Owlready * Reparenting emmo.KiloCoulombPerCubicMetre: {emmo.ElectricChargeDensityUnit, emmo.SINonCoherentUnit, emmo.KiloPrefixedUnit, emmo.PrefixedUnit} => {emmo.ElectricChargeDensityUnit, emmo.SIMetricPrefixedUnit, emmo.KiloPrefixedUnit}
# * Owlready * Reparenting emmo.KiloCoulombPerSquareMetre: {emmo.PrefixedUnit, emmo.SINonCoherentUnit, emmo.KiloPrefixedUnit, emmo.ElectricDisplacementFieldUnit} => {emmo.SIMetricPrefixedUnit, emmo.KiloPrefixedUnit, emmo.ElectricDisplacementFieldUnit}
# * Owlready * Reparenting emmo.KiloCoulomb: {emmo.ElectricChargeUnit, emmo.SINonCoherentUnit, emmo.KiloPrefixedUnit, emmo.PrefixedUnit} => {emmo.ElectricChargeUnit, emmo.SIMetricPrefixedUnit, emmo.KiloPrefixedUnit}
# * Owlready * Reparenting emmo.KiloHertzMetre: {emmo.PrefixedUnit, emmo.SpeedUnit, emmo.SINonCoherentUnit, emmo.KiloPrefixedUnit} => {emmo.SpeedUnit, emmo.SIMetricPrefixedUnit, emmo.KiloPrefixedUnit}
# * Owlready * Reparenting emmo.KiloHertz: {emmo.KiloPrefixedUnit, emmo.SINonCoherentUnit, emmo.FrequencyUnit, emmo.PrefixedUnit} => {emmo.SIMetricPrefixedUnit, emmo.KiloPrefixedUnit, emmo.FrequencyUnit}
# * Owlready * Reparenting emmo.KiloJoulePerKelvin: {emmo.PrefixedUnit, emmo.SINonCoherentUnit, emmo.KiloPrefixedUnit, emmo.EntropyUnit} => {emmo.SIMetricPrefixedUnit, emmo.KiloPrefixedUnit, emmo.EntropyUnit}
# * Owlready * Reparenting emmo.KiloJoulePerKilogramKelvin: {emmo.PrefixedUnit, emmo.EntropyPerMassUnit, emmo.SINonCoherentUnit, emmo.KiloPrefixedUnit} => {emmo.KiloPrefixedUnit, emmo.SIMetricPrefixedUnit, emmo.EntropyPerMassUnit}
# * Owlready * Reparenting emmo.KiloJoulePerKilogram: {emmo.PrefixedUnit, emmo.AbsorbedDoseUnit, emmo.SINonCoherentUnit, emmo.KiloPrefixedUnit} => {emmo.AbsorbedDoseUnit, emmo.SIMetricPrefixedUnit, emmo.KiloPrefixedUnit}
# * Owlready * Reparenting emmo.KiloJoulePerMole: {emmo.PrefixedUnit, emmo.SINonCoherentUnit, emmo.KiloPrefixedUnit, emmo.EnergyPerAmountUnit} => {emmo.SIMetricPrefixedUnit, emmo.KiloPrefixedUnit, emmo.EnergyPerAmountUnit}
# * Owlready * Reparenting emmo.KiloJoule: {emmo.PrefixedUnit, emmo.EnergyUnit, emmo.SINonCoherentUnit, emmo.KiloPrefixedUnit} => {emmo.EnergyUnit, emmo.SIMetricPrefixedUnit, emmo.KiloPrefixedUnit}
# * Owlready * Reparenting emmo.KiloMetrePerSecond: {emmo.PrefixedUnit, emmo.SpeedUnit, emmo.SINonCoherentUnit, emmo.KiloPrefixedUnit} => {emmo.SpeedUnit, emmo.SIMetricPrefixedUnit, emmo.KiloPrefixedUnit}
# * Owlready * Reparenting emmo.KiloMetre: {emmo.PrefixedUnit, emmo.SINonCoherentUnit, emmo.KiloPrefixedUnit, emmo.LengthUnit} => {emmo.SIMetricPrefixedUnit, emmo.KiloPrefixedUnit, emmo.LengthUnit}
# * Owlready * Reparenting emmo.KiloMolePerKilogram: {emmo.AmountPerMassUnit, emmo.SINonCoherentUnit, emmo.KiloPrefixedUnit, emmo.PrefixedUnit} => {emmo.AmountPerMassUnit, emmo.SIMetricPrefixedUnit, emmo.KiloPrefixedUnit}
# * Owlready * Reparenting emmo.KiloMolePerCubicMetre: {emmo.PrefixedUnit, emmo.AmountConcentrationUnit, emmo.SINonCoherentUnit, emmo.KiloPrefixedUnit} => {emmo.AmountConcentrationUnit, emmo.SIMetricPrefixedUnit, emmo.KiloPrefixedUnit}
# * Owlready * Reparenting emmo.KiloMolePerSecond: {emmo.PrefixedUnit, emmo.SINonCoherentUnit, emmo.KiloPrefixedUnit, emmo.CatalyticActivityUnit} => {emmo.SIMetricPrefixedUnit, emmo.KiloPrefixedUnit, emmo.CatalyticActivityUnit}
# * Owlready * Reparenting emmo.KiloMole: {emmo.PrefixedUnit, emmo.SINonCoherentUnit, emmo.AmountUnit, emmo.KiloPrefixedUnit} => {emmo.KiloPrefixedUnit, emmo.SIMetricPrefixedUnit, emmo.AmountUnit}
# * Owlready * Reparenting emmo.KiloNewtonMetre: {emmo.PrefixedUnit, emmo.EnergyUnit, emmo.SINonCoherentUnit, emmo.KiloPrefixedUnit} => {emmo.EnergyUnit, emmo.SIMetricPrefixedUnit, emmo.KiloPrefixedUnit}
# * Owlready * Reparenting emmo.KiloNewtonSquareMetre: {emmo.PrefixedUnit, emmo.ForceAreaUnit, emmo.SINonCoherentUnit, emmo.KiloPrefixedUnit} => {emmo.SIMetricPrefixedUnit, emmo.ForceAreaUnit, emmo.KiloPrefixedUnit}
# * Owlready * Reparenting emmo.KiloNewton: {emmo.ForceUnit, emmo.SINonCoherentUnit, emmo.KiloPrefixedUnit, emmo.PrefixedUnit} => {emmo.ForceUnit, emmo.SIMetricPrefixedUnit, emmo.KiloPrefixedUnit}
# * Owlready * Reparenting emmo.KiloOhm: {emmo.PrefixedUnit, emmo.ElectricResistanceUnit, emmo.SINonCoherentUnit, emmo.KiloPrefixedUnit} => {emmo.ElectricResistanceUnit, emmo.SIMetricPrefixedUnit, emmo.KiloPrefixedUnit}
# * Owlready * Reparenting emmo.KiloPascalPerKelvin: {emmo.PrefixedUnit, emmo.SINonCoherentUnit, emmo.KiloPrefixedUnit, emmo.PressurePerTemperatureUnit} => {emmo.SIMetricPrefixedUnit, emmo.KiloPrefixedUnit, emmo.PressurePerTemperatureUnit}
# * Owlready * Reparenting emmo.KiloPascalPerMilliMetre: {emmo.PrefixedUnit, emmo.SINonCoherentUnit, emmo.KiloPrefixedUnit, emmo.MassPerSquareLengthSquareTimeUnit} => {emmo.SIMetricPrefixedUnit, emmo.KiloPrefixedUnit, emmo.MassPerSquareLengthSquareTimeUnit}
# * Owlready * Reparenting emmo.KiloPascalSquareMetrePerGram: {emmo.PrefixedUnit, emmo.SINonCoherentUnit, emmo.AccelerationUnit, emmo.KiloPrefixedUnit} => {emmo.SIMetricPrefixedUnit, emmo.AccelerationUnit, emmo.KiloPrefixedUnit}
# * Owlready * Reparenting emmo.KiloPascal: {emmo.PrefixedUnit, emmo.SINonCoherentUnit, emmo.KiloPrefixedUnit, emmo.PressureUnit} => {emmo.SIMetricPrefixedUnit, emmo.KiloPrefixedUnit, emmo.PressureUnit}
# * Owlready * Reparenting emmo.KiloSiemensPerMetre: {emmo.PrefixedUnit, emmo.SINonCoherentUnit, emmo.KiloPrefixedUnit, emmo.ElectricConductivityUnit} => {emmo.SIMetricPrefixedUnit, emmo.KiloPrefixedUnit, emmo.ElectricConductivityUnit}
# * Owlready * Reparenting emmo.KiloVoltAmpere: {emmo.PrefixedUnit, emmo.PowerUnit, emmo.SINonCoherentUnit, emmo.KiloPrefixedUnit} => {emmo.PowerUnit, emmo.SIMetricPrefixedUnit, emmo.KiloPrefixedUnit}
# * Owlready * Reparenting emmo.KiloVoltPerMetre: {emmo.PrefixedUnit, emmo.SINonCoherentUnit, emmo.ElectricFieldStrengthUnit, emmo.KiloPrefixedUnit} => {emmo.SIMetricPrefixedUnit, emmo.ElectricFieldStrengthUnit, emmo.KiloPrefixedUnit}
# * Owlready * Reparenting emmo.KiloVolt: {emmo.KiloPrefixedUnit, emmo.SINonCoherentUnit, emmo.ElectricPotentialUnit, emmo.PrefixedUnit} => {emmo.KiloPrefixedUnit, emmo.SIMetricPrefixedUnit, emmo.ElectricPotentialUnit}
# * Owlready * Reparenting emmo.KiloWatt: {emmo.PrefixedUnit, emmo.PowerUnit, emmo.SINonCoherentUnit, emmo.KiloPrefixedUnit} => {emmo.PowerUnit, emmo.SIMetricPrefixedUnit, emmo.KiloPrefixedUnit}
# * Owlready * Reparenting emmo.KiloWeberPerMetre: {emmo.PrefixedUnit, emmo.SINonCoherentUnit, emmo.KiloPrefixedUnit, emmo.MagneticPotentialUnit} => {emmo.SIMetricPrefixedUnit, emmo.KiloPrefixedUnit, emmo.MagneticPotentialUnit}
# * Owlready * Reparenting emmo.KiloWeber: {emmo.PrefixedUnit, emmo.SINonCoherentUnit, emmo.KiloPrefixedUnit, emmo.MagneticFluxUnit} => {emmo.SIMetricPrefixedUnit, emmo.KiloPrefixedUnit, emmo.MagneticFluxUnit}
# * Owlready * Reparenting emmo.KilogramPerCubicCentiMetre: {emmo.PrefixedUnit, emmo.DensityUnit, emmo.SINonCoherentUnit} => {emmo.DensityUnit, emmo.SIMetricPrefixedUnit}
# * Owlready * Reparenting emmo.KilogramPerCubicDeciMetre: {emmo.PrefixedUnit, emmo.DensityUnit, emmo.SINonCoherentUnit} => {emmo.DensityUnit, emmo.SIMetricPrefixedUnit}
# * Owlready * Reparenting emmo.KilogramPerKiloMole: {emmo.PrefixedUnit, emmo.SINonCoherentUnit, emmo.MassPerAmountUnit, emmo.KiloPrefixedUnit} => {emmo.SIMetricPrefixedUnit, emmo.MassPerAmountUnit, emmo.KiloPrefixedUnit}
# * Owlready * Reparenting emmo.KilogramPerMilliMetre: {emmo.PrefixedUnit, emmo.SINonCoherentUnit, emmo.MassPerLengthUnit} => {emmo.SIMetricPrefixedUnit, emmo.MassPerLengthUnit}
# * Owlready * Reparenting emmo.KilogramPerSquareCentiMetre: {emmo.PrefixedUnit, emmo.SINonCoherentUnit, emmo.AreaDensityUnit} => {emmo.SIMetricPrefixedUnit, emmo.AreaDensityUnit}
# * Owlready * Reparenting emmo.KilogramPerSquareKiloMetre: {emmo.PrefixedUnit, emmo.SINonCoherentUnit, emmo.AreaDensityUnit, emmo.KiloPrefixedUnit} => {emmo.SIMetricPrefixedUnit, emmo.AreaDensityUnit, emmo.KiloPrefixedUnit}
# * Owlready * Reparenting emmo.KilogramSquareCentiMetre: {emmo.PrefixedUnit, emmo.MassAreaUnit, emmo.SINonCoherentUnit, emmo.KiloPrefixedUnit} => {emmo.MassAreaUnit, emmo.SIMetricPrefixedUnit, emmo.KiloPrefixedUnit}
# * Owlready * Reparenting emmo.KilogramSquareMilliMetre: {emmo.PrefixedUnit, emmo.MassAreaUnit, emmo.SINonCoherentUnit, emmo.KiloPrefixedUnit} => {emmo.MassAreaUnit, emmo.SIMetricPrefixedUnit, emmo.KiloPrefixedUnit}
# * Owlready * Reparenting emmo.MegaAmpere: {emmo.PrefixedUnit, emmo.ElectricCurrentUnit, emmo.SINonCoherentUnit, emmo.MegaPrefixedUnit} => {emmo.ElectricCurrentUnit, emmo.SIMetricPrefixedUnit, emmo.MegaPrefixedUnit}
# * Owlready * Reparenting emmo.MegaBecquerel: {emmo.PrefixedUnit, emmo.SINonCoherentUnit, emmo.MegaPrefixedUnit, emmo.FrequencyUnit} => {emmo.SIMetricPrefixedUnit, emmo.MegaPrefixedUnit, emmo.FrequencyUnit}
# * Owlready * Reparenting emmo.MegaCoulombPerCubicMetre: {emmo.ElectricChargeDensityUnit, emmo.SINonCoherentUnit, emmo.MegaPrefixedUnit, emmo.PrefixedUnit} => {emmo.ElectricChargeDensityUnit, emmo.SIMetricPrefixedUnit, emmo.MegaPrefixedUnit}
# * Owlready * Reparenting emmo.MegaCoulombPerSquareMetre: {emmo.PrefixedUnit, emmo.SINonCoherentUnit, emmo.MegaPrefixedUnit, emmo.ElectricDisplacementFieldUnit} => {emmo.SIMetricPrefixedUnit, emmo.MegaPrefixedUnit, emmo.ElectricDisplacementFieldUnit}
# * Owlready * Reparenting emmo.MegaCoulomb: {emmo.ElectricChargeUnit, emmo.SINonCoherentUnit, emmo.MegaPrefixedUnit, emmo.PrefixedUnit} => {emmo.ElectricChargeUnit, emmo.SIMetricPrefixedUnit, emmo.MegaPrefixedUnit}
# * Owlready * Reparenting emmo.MegaGramPerCubicMetre: {emmo.PrefixedUnit, emmo.DensityUnit, emmo.SINonCoherentUnit, emmo.MegaPrefixedUnit} => {emmo.DensityUnit, emmo.SIMetricPrefixedUnit, emmo.MegaPrefixedUnit}
# ...
# * Owlready * Reparenting emmo.CaesiumSymbol: {emmo.ChemicalElement} => {emmo.ChemicalElement, emmo.NCNameData, emmo.LanguageData}
# * Owlready * Reparenting emmo.RubidiumSymbol: {emmo.ChemicalElement} => {emmo.ChemicalElement, emmo.NCNameData, emmo.LanguageData}
# * Owlready * Reparenting emmo.HeliumSymbol: {emmo.ChemicalElement} => {emmo.ChemicalElement, emmo.NCNameData, emmo.LanguageData}
# * Owlready * Reparenting emmo.OsmiumSymbol: {emmo.ChemicalElement} => {emmo.ChemicalElement, emmo.NCNameData, emmo.LanguageData}
# * Owlready * Reparenting emmo.XenonSymbol: {emmo.ChemicalElement} => {emmo.ChemicalElement, emmo.NCNameData, emmo.LanguageData}
# * Owlready * Reparenting emmo.AluminiumSymbol: {emmo.ChemicalElement} => {emmo.ChemicalElement, emmo.NCNameData, emmo.LanguageData}
# * Owlready * Reparenting emmo.YtterbiumSymbol: {emmo.ChemicalElement} => {emmo.ChemicalElement, emmo.NCNameData, emmo.LanguageData}
# * Owlready * Reparenting emmo.CaliforniumSymbol: {emmo.ChemicalElement} => {emmo.ChemicalElement, emmo.NCNameData, emmo.LanguageData}
# * Owlready * Reparenting emmo.URI: {emmo.IRI, emmo.ComputerScience} => {emmo.IRI}
# * Owlready * Reparenting emmo.AtomicNumber: {emmo.IntegerData, emmo.PureNumberQuantity} => {emmo.Information, emmo.IntegerData, emmo.PureNumberQuantity}
# * Owlready * Reparenting emmo.JSONData: {emmo.ComputerScience} => {emmo.SymbolicData, emmo.ComputerScience}
# * Owlready * Reparenting emmo.MathematicalModel: {owl.Thing} => {emmo.AnalogicalIcon, emmo.Information, emmo.Mathematical}
# * Owlready * Reparenting emmo.NonSIUnit: {owl.Thing} => {emmo.MeasurementUnit}
# * Owlready * Reparenting emmo.SIUnit: {emmo.SystemUnit} => {emmo.SystemUnit, emmo.MeasurementUnitByPrefix}
# * Owlready * Reparenting emmo.SIDerivedUnit: {emmo.DerivedUnit} => {emmo.SIUnit, emmo.DerivedUnit}
# * Owlready * Reparenting emmo.SICoherentDerivedUnit: {emmo.DerivedUnit} => {emmo.SICoherentUnit, emmo.SIDerivedUnit}
# * Owlready * Reparenting emmo.DegreeCelsiusKilogramPerSquareMetre: {emmo.TemperatureMassPerAreaUnit, emmo.SICoherentUnit} => {emmo.TemperatureMassPerAreaUnit, emmo.SICoherentDerivedUnit}
# * Owlready * Reparenting emmo.KilogramKelvin: {emmo.MassTemperatureUnit, emmo.SICoherentDerivedUnit, emmo.NonPrefixedUnit} => {emmo.MassTemperatureUnit, emmo.SICoherentDerivedUnit}
# * Owlready * Reparenting emmo.KilogramMetrePerSecond: {emmo.SICoherentDerivedUnit, emmo.MomentumUnit, emmo.NonPrefixedUnit} => {emmo.SICoherentDerivedUnit, emmo.MomentumUnit}
# * Owlready * Reparenting emmo.KilogramPerCubicMetrePerSecond: {emmo.SICoherentDerivedUnit, emmo.NonPrefixedUnit, emmo.MassPerVolumeTimeUnit} => {emmo.SICoherentDerivedUnit, emmo.MassPerVolumeTimeUnit}
# * Owlready * Reparenting emmo.KilogramPerCubicMetre: {emmo.SICoherentDerivedUnit, emmo.DensityUnit, emmo.NonPrefixedUnit} => {emmo.SICoherentDerivedUnit, emmo.DensityUnit}
# * Owlready * Reparenting emmo.KilogramPerKilogram: {emmo.SICoherentDerivedUnit, emmo.MassFractionUnit, emmo.NonPrefixedUnit} => {emmo.SICoherentDerivedUnit, emmo.MassFractionUnit}
# * Owlready * Reparenting emmo.KilogramPerMetrePerSecond: {emmo.SICoherentDerivedUnit, emmo.MassPerLengthTimeUnit, emmo.NonPrefixedUnit} => {emmo.SICoherentDerivedUnit, emmo.MassPerLengthTimeUnit}
# * Owlready * Reparenting emmo.KilogramPerMetrePerSquareSecond: {emmo.SICoherentDerivedUnit, emmo.NonPrefixedUnit, emmo.PressureUnit} => {emmo.SICoherentDerivedUnit, emmo.PressureUnit}
# * Owlready * Reparenting emmo.KilogramPerMetre: {emmo.SICoherentDerivedUnit, emmo.MassPerLengthUnit, emmo.NonPrefixedUnit} => {emmo.SICoherentDerivedUnit, emmo.MassPerLengthUnit}
# * Owlready * Reparenting emmo.KilogramPerMole: {emmo.SICoherentDerivedUnit, emmo.MassPerAmountUnit, emmo.NonPrefixedUnit} => {emmo.SICoherentDerivedUnit, emmo.MassPerAmountUnit}
# * Owlready * Reparenting emmo.KilogramPerSecondPerSquareMetre: {emmo.SICoherentDerivedUnit, emmo.MassFluxUnit, emmo.NonPrefixedUnit} => {emmo.SICoherentDerivedUnit, emmo.MassFluxUnit}
# * Owlready * Reparenting emmo.KilogramPerSecond: {emmo.SICoherentDerivedUnit, emmo.MassPerTimeUnit, emmo.NonPrefixedUnit} => {emmo.SICoherentDerivedUnit, emmo.MassPerTimeUnit}
# * Owlready * Reparenting emmo.KilogramPerSquareMetrePerPascalPerSecond: {emmo.TimePerLengthUnit, emmo.SICoherentDerivedUnit, emmo.NonPrefixedUnit} => {emmo.TimePerLengthUnit, emmo.SICoherentDerivedUnit}
# * Owlready * Reparenting emmo.KilogramPerSquareMetrePerSecond: {emmo.SICoherentDerivedUnit, emmo.MassFluxUnit, emmo.NonPrefixedUnit} => {emmo.SICoherentDerivedUnit, emmo.MassFluxUnit}
# * Owlready * Reparenting emmo.KilogramPerSquareMetreSquareSecond: {emmo.SICoherentDerivedUnit, emmo.NonPrefixedUnit, emmo.MassPerSquareLengthSquareTimeUnit} => {emmo.SICoherentDerivedUnit, emmo.MassPerSquareLengthSquareTimeUnit}
# * Owlready * Reparenting emmo.KilogramPerSquareMetre: {emmo.SICoherentDerivedUnit, emmo.NonPrefixedUnit, emmo.AreaDensityUnit} => {emmo.SICoherentDerivedUnit, emmo.AreaDensityUnit}
# * Owlready * Reparenting emmo.KilogramPerSquareSecond: {emmo.SICoherentDerivedUnit, emmo.NonPrefixedUnit, emmo.ForcePerLengthUnit} => {emmo.SICoherentDerivedUnit, emmo.ForcePerLengthUnit}
# * Owlready * Reparenting emmo.KilogramSquareMetrePerSecond: {emmo.SICoherentDerivedUnit, emmo.NonPrefixedUnit, emmo.AngularMomentumUnit} => {emmo.SICoherentDerivedUnit, emmo.AngularMomentumUnit}
# * Owlready * Reparenting emmo.KilogramSquareMetre: {emmo.SICoherentDerivedUnit, emmo.MassAreaUnit, emmo.NonPrefixedUnit} => {emmo.SICoherentDerivedUnit, emmo.MassAreaUnit}
# * Owlready * Reparenting emmo.KilogramSquareSecond: {emmo.SICoherentDerivedUnit, emmo.MassSquareTimeUnit, emmo.NonPrefixedUnit} => {emmo.SICoherentDerivedUnit, emmo.MassSquareTimeUnit}
# * Owlready * Reparenting emmo.MoleDegreeCelsius: {emmo.SICoherentDerivedUnit, emmo.NonPrefixedUnit, emmo.AmountTemperatureUnit} => {emmo.SICoherentDerivedUnit, emmo.AmountTemperatureUnit}
# * Owlready * Reparenting emmo.SINonCoherentDerivedUnit: {emmo.DerivedUnit} => {emmo.SINonCoherentUnit, emmo.SIDerivedUnit}
# * Owlready * Reparenting emmo.AmperePerGram: {emmo.SINonCoherentUnit, emmo.NonPrefixedUnit, emmo.ElectricCurrentPerMassUnit} => {emmo.SINonCoherentDerivedUnit, emmo.ElectricCurrentPerMassUnit}
# * Owlready * Reparenting emmo.GramPerCubicMetre: {emmo.MeasurementUnit, emmo.DensityUnit, emmo.SINonCoherentUnit, emmo.NonPrefixedUnit} => {emmo.SINonCoherentDerivedUnit, emmo.DensityUnit}
# * Owlready * Reparenting emmo.GramPerGram: {emmo.MeasurementUnit, emmo.SINonCoherentUnit, emmo.MassFractionUnit, emmo.NonPrefixedUnit} => {emmo.SINonCoherentDerivedUnit, emmo.MassFractionUnit}
# * Owlready * Reparenting emmo.GramPerKilogram: {emmo.SINonCoherentUnit, emmo.MassFractionUnit, emmo.NonPrefixedUnit} => {emmo.SINonCoherentDerivedUnit, emmo.MassFractionUnit}
# * Owlready * Reparenting emmo.GramPerMetre: {emmo.MeasurementUnit, emmo.SINonCoherentUnit, emmo.MassPerLengthUnit, emmo.NonPrefixedUnit} => {emmo.SINonCoherentDerivedUnit, emmo.MassPerLengthUnit}
# * Owlready * Reparenting emmo.GramPerMole: {emmo.MassPerAmountUnit, emmo.SINonCoherentUnit, emmo.NonPrefixedUnit, emmo.MeasurementUnit} => {emmo.SINonCoherentDerivedUnit, emmo.MassPerAmountUnit}
# * Owlready * Reparenting emmo.GramPerSecond: {emmo.MassPerTimeUnit, emmo.SINonCoherentUnit, emmo.NonPrefixedUnit, emmo.MeasurementUnit} => {emmo.SINonCoherentDerivedUnit, emmo.MassPerTimeUnit}
# * Owlready * Reparenting emmo.GramPerSquareMetre: {emmo.MeasurementUnit, emmo.SINonCoherentUnit, emmo.NonPrefixedUnit, emmo.AreaDensityUnit} => {emmo.SINonCoherentDerivedUnit, emmo.AreaDensityUnit}
# * Owlready * Reparenting emmo.JoulePerGram: {emmo.MeasurementUnit, emmo.AbsorbedDoseUnit, emmo.SINonCoherentUnit, emmo.NonPrefixedUnit} => {emmo.SINonCoherentDerivedUnit, emmo.AbsorbedDoseUnit}
# * Owlready * Reparenting emmo.SquareMetrePerGram: {emmo.AreaPerMassUnit, emmo.SINonCoherentUnit, emmo.NonPrefixedUnit, emmo.MeasurementUnit} => {emmo.SINonCoherentDerivedUnit, emmo.AreaPerMassUnit}
# * Owlready * Reparenting emmo.SICoherentUnit: {owl.Thing} => {emmo.SIUnit, emmo.NonPrefixedUnit}
# * Owlready * Reparenting emmo.SINonCoherentUnit: {owl.Thing} => {emmo.SIUnit}
# * Owlready * Reparenting emmo.SIAcceptedDerivedUnit: {emmo.DerivedUnit} => {emmo.DerivedUnit, emmo.SIAccepted}
# * Owlready * Reparenting emmo.SIAccepted: {emmo.MeasurementUnit} => {emmo.MeasurementUnitByPrefix}
# * Owlready * Reparenting emmo.ChemicalNomenclature: {emmo.Chemical} => {emmo.ChemicalSpecies}
# * Owlready * Reparenting emmo.ResourceIdentifier: {emmo.ComputerScience} => {emmo.ComputerScience, emmo.Information, emmo.Conventional}
# * Owlready * Reparenting emmo.ApplicationProgram: {emmo.Software} => {emmo.Program}
# * Owlready * Reparenting emmo.SimulationApplication: {emmo.FunctionalIcon, emmo.ApplicationProgram} => {emmo.FunctionalIcon, emmo.Information, emmo.ApplicationProgram}
# * Owlready * Reparenting emmo.SystemProgram: {emmo.Software} => {emmo.Program}
# * Owlready * Reparenting emmo.File: {emmo.SystemResource, emmo.DigitalData} => {emmo.SystemResource, emmo.Referent, emmo.DigitalData}
# * Owlready * Reparenting emmo.Information: {owl.Thing} => {emmo.Sign, emmo.Data}
# * Owlready * Reparenting emmo.Auditory: {owl.Thing} => {emmo.Perceptual}
# * Owlready * Reparenting emmo.Somatosensory: {owl.Thing} => {emmo.Perceptual}
# * Owlready * Reparenting emmo.Visual: {owl.Thing} => {emmo.Perceptual}
# * Owlready * Reparenting emmo.Gustatory: {owl.Thing} => {emmo.Perceptual}
# * Owlready * Reparenting emmo.Olfactory: {owl.Thing} => {emmo.Perceptual}
# * Owlready * Reparenting emmo.Product: {emmo.Maximal} => {emmo.Persistence, emmo.Maximal}
# * Owlready * Reparenting emmo.Experiment: {emmo.Observation} => {emmo.Observation, emmo.Object}
# * Owlready * Reparenting emmo.Theorisation: {emmo.Determination} => {emmo.Object, emmo.Determination}
# * Owlready * Reparenting emmo.Quantity: {emmo.Property} => {emmo.Referent, emmo.Property}
# * Owlready * Reparenting emmo.SuperconductorEnergyGap: {emmo.GapEnergy, emmo.CondensedMatterPhysicsQuantity} => {emmo.GapEnergy}
# * Owlready * Reparenting emmo.AmountOfSubstance: {emmo.Extensive, emmo.PhysioChemicalQuantity} => {emmo.Extensive, emmo.ISQBaseQuantity, emmo.PhysioChemicalQuantity}
# * Owlready * Reparenting emmo.ElectricCurrent: {emmo.Extensive, emmo.ElectromagneticQuantity} => {emmo.Extensive, emmo.ISQBaseQuantity, emmo.ElectromagneticQuantity}
# * Owlready * Reparenting emmo.Length: {emmo.Extensive, emmo.SpaceAndTimeQuantity} => {emmo.Extensive, emmo.ISQBaseQuantity, emmo.SpaceAndTimeQuantity}
# * Owlready * Reparenting emmo.Mass: {emmo.Extensive, emmo.MechanicalQuantity} => {emmo.Extensive, emmo.ISQBaseQuantity, emmo.MechanicalQuantity}
# * Owlready * Reparenting emmo.NuclidicMass: {emmo.AtomicAndNuclearPhysicsQuantity, emmo.RestMass} => {emmo.RestMass}
# * Owlready * Reparenting emmo.ISQBaseQuantity: {emmo.BaseQuantity, emmo.InternationalSystemOfQuantity} => {emmo.BaseQuantity, emmo.InternationalSystemOfQuantity, emmo.ISO80000Categorised}
# * Owlready * Reparenting emmo.LuminousIntensity: {emmo.LightAndRadiationQuantity} => {emmo.LightAndRadiationQuantity, emmo.ISQBaseQuantity}
# * Owlready * Reparenting emmo.ThermodynamicTemperature: {emmo.ThermodynamicalQuantity, emmo.Intensive} => {emmo.ISQBaseQuantity, emmo.ThermodynamicalQuantity, emmo.Intensive}
# * Owlready * Reparenting emmo.DewPointTemperature: {emmo.ThermodynamicTemperature, emmo.ThermodynamicalQuantity} => {emmo.ThermodynamicTemperature}
# * Owlready * Reparenting emmo.Time: {emmo.SpaceAndTimeQuantity} => {emmo.ISQBaseQuantity, emmo.SpaceAndTimeQuantity}
# * Owlready * Reparenting emmo.TotalCrossSection: {emmo.AtomicAndNuclearPhysicsQuantity, emmo.AtomicPhysicsCrossSection} => {emmo.AtomicPhysicsCrossSection}
# * Owlready * Reparenting emmo.GFactorOfNucleusOrNuclearParticle: {emmo.GFactor, emmo.AtomicAndNuclearPhysicsQuantity} => {emmo.GFactor}
# * Owlready * Reparenting emmo.LandeFactor: {emmo.GFactor, emmo.AtomicAndNuclearPhysicsQuantity} => {emmo.GFactor}
# * Owlready * Reparenting emmo.StandardEquilibriumConstant: {emmo.PhysioChemicalQuantity, emmo.EquilibriumConstant} => {emmo.EquilibriumConstant}
# * Owlready * Reparenting emmo.StandardAbsoluteActivity: {emmo.PhysioChemicalQuantity, emmo.AbsoluteActivity} => {emmo.AbsoluteActivity}
# * Owlready * Reparenting emmo.StandardAbsoluteActivityOfSolvent: {emmo.PhysioChemicalQuantity, emmo.AbsoluteActivity} => {emmo.AbsoluteActivity}
# * Owlready * Reparenting emmo.StandardAbsoluteActivity: {emmo.PhysioChemicalQuantity, emmo.AbsoluteActivity} => {emmo.AbsoluteActivity}
# * Owlready * Reparenting emmo.ParticleConcentration: {emmo.ISQDerivedQuantity, emmo.PhysioChemicalQuantity, emmo.Concentration} => {emmo.PhysioChemicalQuantity, emmo.Concentration}
# * Owlready * Reparenting emmo.MolecularConcentration: {emmo.ISQDerivedQuantity, emmo.PhysioChemicalQuantity, emmo.Concentration} => {emmo.PhysioChemicalQuantity, emmo.Concentration}
# * Owlready * Reparenting emmo.KineticFrictionFactor: {emmo.MechanicalQuantity, emmo.CoefficientOfFriction} => {emmo.CoefficientOfFriction}
# * Owlready * Reparenting emmo.StaticFrictionCoefficient: {emmo.MechanicalQuantity, emmo.CoefficientOfFriction} => {emmo.CoefficientOfFriction}
# * Owlready * Reparenting emmo.DebyeAngularWaveNumber: {emmo.AngularWaveNumber, emmo.CondensedMatterPhysicsQuantity} => {emmo.AngularWaveNumber}
# * Owlready * Reparenting emmo.SurfaceCoefficientOfHeatTransfer: {emmo.CoefficientOfHeatTransfer, emmo.ThermodynamicalQuantity} => {emmo.CoefficientOfHeatTransfer}
# * Owlready * Reparenting emmo.CubicExpansionCoefficient: {emmo.ThermodynamicalQuantity, emmo.CoefficientOfThermalExpansion} => {emmo.CoefficientOfThermalExpansion}
# * Owlready * Reparenting emmo.LinearExpansionCoefficient: {emmo.ThermodynamicalQuantity, emmo.CoefficientOfThermalExpansion} => {emmo.CoefficientOfThermalExpansion}
# * Owlready * Reparenting emmo.AmountConcentration: {emmo.ISQDerivedQuantity, emmo.ChemicalCompositionQuantity, emmo.Concentration, emmo.Intensive} => {emmo.ChemicalCompositionQuantity, emmo.Concentration, emmo.Intensive}
# * Owlready * Reparenting magnetic_material_mammos.Reflectivity: {emmo.Property} => {emmo.PhysicalQuantity}
# * Owlready * Reparenting magnetic_material_mammos.GeometricalSize: {emmo.Property} => {emmo.Referent, emmo.Property}
# * Owlready * Reparenting magnetic_material_mammos.MagneticHysteresisProperties: {emmo.Property} => {emmo.Referent, emmo.Property}
# * Owlready * Reparenting magnetic_material_mammos.CrystallographicOrientation: {emmo.Property} => {emmo.Referent, emmo.Property}
# * Owlready * Reparenting magnetic_material_mammos.UniaxialMagneticAnisotropy: {magnetic_material_mammos.MagneticAnisotropy} => {emmo.Referent, magnetic_material_mammos.MagneticAnisotropy}
# * Owlready * Reparenting magnetic_material_mammos.ExtrinsicMagneticProperties: {emmo.Property} => {emmo.Referent, emmo.Property}
# * Owlready * Reparenting magnetic_material_mammos.GrainSizeDistribution: {emmo.Property} => {emmo.Referent, emmo.Property}
# * Owlready * Reparenting magnetic_material_mammos.CubicMagnetocrystallineAnisotropy: {magnetic_material_mammos.MagneticAnisotropy} => {emmo.Referent, magnetic_material_mammos.MagneticAnisotropy}
# * Owlready * Reparenting magnetic_material_mammos.IntrinsicMagneticProperties: {emmo.Property} => {emmo.Referent, emmo.Property}
# * Owlready * Reparenting magnetic_material_mammos.SampleGeometry: {emmo.Property} => {emmo.Referent, emmo.Property}
# * Owlready * Reparenting magnetic_material_mammos.MagnetocrystallineAnisotropy: {emmo.Property} => {emmo.Referent, emmo.Property}
# * Owlready * Reparenting magnetic_material_mammos.ShapeAnisotropy: {magnetic_material_mammos.MagneticAnisotropy} => {emmo.Referent, magnetic_material_mammos.MagneticAnisotropy}
# * Owlready * Reparenting emmo.Replica: {emmo.Icon} => {emmo.ResemblanceIcon, emmo.FunctionalIcon}
# * Owlready * Reparenting emmo.Manufacturer: {owl.Thing} => {emmo.Process}
# * Owlready * Reparenting emmo.Tool: {emmo.Object, emmo.Participant} => {emmo.Participant}
# * Owlready * (NB: only changes on entities loaded in Python are shown, other changes are done but not listed)

# %% [markdown]
# ## Creating entities
#
# For entities that are important in MaMMoS, there are [convenient attributes](https://mammos-project.github.io/mammos/api/mammos_entity.html) to define those. For example for the saturation magnetization Ms:

# %%
Ms = me.Ms(800e3)  # defines Ms = 8e5 A/m  (default units are SI, i.e. A/m here)

# %%
Ms
# Out:
# Entity(ontology_label='SpontaneousMagnetization', value=np.float64(800000.0), unit='A / m')

# %% [markdown]
# If no units are provided, then the ontology units are used, such as `A/m` in the example above. These units are SI units typically without numerical prefactors (such as kilo, milli, etc.)
#
# If units are provided, these are compared with the units expected for that entity. An error is raised if they do not match. This is good practice for extra clarity.

# %%
M1 = me.Ms(800e3, "A/m")
M1
# Out:
# Entity(ontology_label='SpontaneousMagnetization', value=np.float64(800000.0), unit='A / m')

# %% [markdown]
# Providing units can be also useful, if numerical prefactors are used (such as kilo):

# %%
M2 = me.Ms(800, "kA/m")
M2
# Out:
# Entity(ontology_label='SpontaneousMagnetization', value=np.float64(800.0), unit='kA / m')

# %%
M1 == M2
# Out:
# True

# %% [markdown]
# We can create an entity from a Quantity as well:

# %%
import mammos_units as u

Ms_quantity = 800 * u.kA / u.m
Ms_quantity
# Out:
# <Quantity 800. kA / m>

# %%
me.Ms(Ms_quantity)
# Out:
# Entity(ontology_label='SpontaneousMagnetization', value=np.float64(800.0), unit='kA / m')

# %% [markdown]
# If we like to express spontaneous magnetization in Tesla, we can convert it to the required A/m. To allow that conversion we must explicitely enable the `magnetic_flux_field` equivalency ($B=\mu_0H$):

# %%
# enable implicit conversion between A/m and T in the rest of the notebook:
u.set_enabled_equivalencies(u.magnetic_flux_field())

a = 1.2 * u.T  # Quantity in Tesla

Ms = me.Ms(a.to("A/m"))  # Convert Quantity to A/m and create entity
Ms
# Out:
# Entity(ontology_label='SpontaneousMagnetization', value=np.float64(954929.6580315315), unit='A / m')

# %% [markdown]
# As a cross-check we can access the quantity attribute and convert that back to Tesla. This operation does not modify `Ms`.

# %%
Ms.q.to("T")
# Out:
# <Quantity 1.2 T>

# %% [markdown]
# Initializing with incompatible units fails with an error. In particular, implicit conversion via equivalencies is not supported. Convert to the required units first, as shown above.

# %%
me.Ms(1.2, "T")  # Tesla not compatible with A/m
# Out:
# ---------------------------------------------------------------------------
# UnitConversionError                       Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 me.Ms(1.2, "T")  # Tesla not compatible with A/m
#
# File ~/repos/mammos-devtools/packages/mammos-entity/src/mammos_entity/_entities.py:217, in Ms(value, unit)
#     202 def Ms(
#     203     value: int | float | numpy.typing.ArrayLike = 0, unit: None | str = None
#     204 ) -> mammos_entity.Entity:
#     205     """Create an Entity representing the spontaneous magnetization (Ms).
#     206
#     207     Args:
#    (...)    215
#     216     """
# --> 217     return Entity("SpontaneousMagnetization", value, unit)
#
# File ~/repos/mammos-devtools/packages/mammos-entity/src/mammos_entity/_base.py:151, in Entity.__init__(self, ontology_label, value, unit)
#     149     with u.set_enabled_equivalencies(None):
#     150         if not u.Unit(si_unit).is_equivalent(unit):
# --> 151             raise u.UnitConversionError(
#     152                 f"The unit '{unit}' is not equivalent to the unit of"
#     153                 f" {ontology_label} '{u.Unit(si_unit)}'"
#     154             )
#     155 elif (si_unit is not None) and (unit is None):
#     156     with u.add_enabled_aliases({"Cel": u.K, "mCel": u.K}):
#
# UnitConversionError: The unit 'T' is not equivalent to the unit of SpontaneousMagnetization 'A / m'

# %% [markdown]
# For more details about unit conversion and equivalencies refer to the documentation of [mammos-units](https://mammos-project.github.io/mammos/examples/mammos-units/example.html#Equivalency).

# %% [markdown]
# ## Access to ontology
#
# Each entity object knows its label in the ontology:

# %%
Ms.ontology_label
# Out:
# 'SpontaneousMagnetization'

# %% [markdown]
# The ontology attribute links to an [owlready2](https://github.com/pwin/owlready2) object created by the [EMMOntoPy](https://emmo-repo.github.io/EMMOntoPy/stable/) package.

# %% [markdown]
# When saving data to a file, the attribute `ontology_label_with_iri` might be useful to save in the metadata as it returns a string containing the ontology label together with the unique identifier of the ontology entry (IRI is the Internationalized Resource Identifier).

# %%
Ms.ontology_label_with_iri
# Out:
# 'SpontaneousMagnetization https://w3id.org/emmo/domain/magnetic_material#EMMO_032731f8-874d-5efb-9c9d-6dafaa17ef25'

# %% [markdown]
# We can use all attributes of the ontology object through `Ms.ontology`:

# %%
Ms.ontology.get_annotations()
# Out:
# {'prefLabel': [locstr('SpontaneousMagnetization', 'en')],
#  'altLabel': ['Ms'],
#  'elucidation': [locstr('The spontaneous magnetization, Ms, of a ferromagnet is the result\nof alignment of the magnetic moments of individual atoms. Ms exists\nwithin a domain of a ferromagnet.', 'en')],
#  'IECEntry': ['https://www.electropedia.org/iev/iev.nsf/display?openform&ievref=221-02-41'],
#  'wikipediaReference': ['https://en.wikipedia.org/wiki/Spontaneous_magnetization']}

# %%
print(Ms.ontology.elucidation[0])
# Out:
# The spontaneous magnetization, Ms, of a ferromagnet is the result
# of alignment of the magnetic moments of individual atoms. Ms exists
# within a domain of a ferromagnet.

# %% [markdown]
# ## Entities contain Quantities

# %% [markdown]
# Each entity has a `quantity` attribute containing the `mammos_units.Quantity` object. See [mammos_units examples](https://mammos-project.github.io/mammos/examples/mammos-units/index.html) for details.

# %%
Ms.quantity
# Out:
# <Quantity 954929.65803153 A / m>

# %% [markdown]
# There is also the shorthand `q` for the `quantity` attribute:

# %%
Ms.q
# Out:
# <Quantity 954929.65803153 A / m>

# %% [markdown]
# The attributes `value` and `unit` provide direct access to value and unit of the quantity:

# %%
Ms.value
# Out:
# np.float64(954929.6580315315)

# %%
Ms.unit
# Out:
# Unit("A / m")

# %% [markdown]
# Entities do not support numerical operations. To perform these operations, we first need to extract the quantity:

# %%
Ms.q**2
# Out:
# <Quantity 9.11890652e+11 A2 / m2>

# %%
Ms.quantity.to("kA/m")
# Out:
# <Quantity 954.92965803 kA / m>

# %%
Ms.quantity.to("T")
# Out:
# <Quantity 1.2 T>

# %% [markdown]
# ## Defining vector entities (Example Zeeman field)

# %%
H = me.H([1e4, 1e4, 1e4], "A/m")
H
# Out:
# Entity(ontology_label='ExternalMagneticField', value=array([10000., 10000., 10000.]), unit='A / m')

# %%
H.ontology
# Out:
# magnetic_material.ExternalMagneticField

# %%
print(H.ontology.elucidation[0])
# Out:
# The external field H′, acting on a sample that is produced by
# electric currents or the stray field of magnets outside the sample
# volume, is often called the applied field.

# %% [markdown]
# ## Does `mammos_entity` not provide your preferred entity?

# %% [markdown]
# The list of convenience attributes is at
# https://mammos-project.github.io/mammos/api/mammos_entity.html
#
# If the desired entity is not available, we can search the EMMO ontology (including the `magnetic_material_mammos` additions), for example for entity labels containing the string "Magnetization":

# %%
me.mammos_ontology.get_by_label_all("*Field*")
# Out:
# {emmo.ElectricDisplacementFieldUnit,
#  emmo.ElectricFieldStrength,
#  emmo.ElectricFieldStrengthUnit,
#  emmo.MagneticFieldStrength,
#  emmo.MagneticFieldStrengthUnit,
#  magnetic_material.AnisotropyField,
#  magnetic_material.DemagnetizingField,
#  magnetic_material.ExternalMagneticField,
#  magnetic_material.InternalMagneticField,
#  magnetic_material.KneeField,
#  magnetic_material.KneeFieldExternal,
#  magnetic_material.SwitchingFieldCoercivity,
#  magnetic_material.SwitchingFieldCoercivityExternal}

# %% [markdown]
# Once identified the right label, we create an entity like this:

# %%
me.Entity("ElectricFieldStrength", value=230)
# Out:
# Entity(ontology_label='ElectricFieldStrength', value=np.float64(230.0), unit='V / m')
